# %% [markdown]
# # Homework 1: Language models (58 points)
#
# The first homework focuses on the following skills: being able to work with concpetual & formal exercises on language modeling and neural networks, understanding configurations of state-of-the-art language models and, finally, fine-tuning a language model yourself!
#
# ### Logistics
#
# * submission deadline: May 13th 23:59 German time via Moodle
#   * please upload a **SINGLE ZIP FILE named Surname_FirstName_HW1.zip** containing the .ipynb file of the notebook (if you solve it on Colab, you can go to File > download).
# * please make sure to **KEEP** the outputs of your notebook cells where needed, so that we can inspect them.
# * please solve and submit the homework **individually**!
# * if you use Colab, to speed up the execution of the code on Colab (especially Exercise 3), you can use the available GPU (if Colab resources allow). For that, before executing your code, navigate to Runtime > Change runtime type > GPU > Save.

# %% [markdown]
# ## Exercise 1: Understanding language modeling (12 points)
#
# Please answer the following exercises. Importantly, please reason step by step; i.e., where calculations are required, please provide intermediate steps of how you arrived at your solution. You do not need to write any code, just mathematical solutions.
#
# > 1. [6pts] Consider the corpus $C$ with the following sentences: $C=${"The cat sneezes", "The bird sings", "The cat sneezes", "A dog sings"}.
# > (a) Define the vocabulary $V$ of this corpus (assuming by-word tokenization).
# > (b) Pick one of the four sentences in $C$. Formulate the probability of that sentence in the form of the chain rule. Calculate the probability of each termn in the chain rule, given the corpus (assuming that there is, additionally, a start-of-sequence and an end-of-sequence token).
# > 2. [4pts] We want to train a neural network that takes as input two numbers $x_1, x_2$, passes them through three hidden linear layers, each with 13 neurons, each followed by the ReLU activation function, and outputs three numbers $y_1, y_2, y_3$. Write down all weight matrices of this network with their dimensions. (Example: if one weight matrix has the dimensions 3x5, write $M_1\in R^{3\times5}$)
# > 3. [2pts] Consider the sequence: "Input: Some students trained each language model". Assuming that each word+space/punctuation corresponds to one token, consider the following token probabilities of this sequence under some trained language model: $p = [0.67, 0.91, 0.83, 0.40, 0.29, 0.58, 0.75]$. Compute the average surprisal of this sequence under that language model. [Note: in this class we always assume the base $e$ for $log$, unless indicated otherwise. This is also usually the case throughout NLP.]

# %% [markdown]
# ### Exercise 1. Answers:
#
# #### 1.
# **(a)**   `V = {"the", "cat", "sneezes", "bird", "sings", "a", "dog", <s>, </s>}`
#
# **(b)**
# * Sentence: `"The bird sings"`
# * We compute:
# `**P(the bird sings) = P(the|<s>) . P(bird|the) . P(sings|bird) . P(</s>| sings)**`
#
# * **Individually, the bigram probabilities are:**
#   - `P(the | <s>) = 3/4 = 0.75`
#   - `P(bird | the) = 1/4 = 0.25`
#   - `P(sings | bird) = 1/4 = 0.25`
#   - `P(</s> | sings) = 2/4 = 0.5`
#
# * **Applying the chain rule:**
# - `P(the bird sings) = 0.75 × 0.25 × 0.25 × 0.5 = 0.0234375`
# ---
#
# #### 2.
#
#
# 1. **Hidden Layer**:
#   - 2 inputs passes through 13 dimensional hidden layer. Output size is 13 because it has 13 neurons.
#   - Weight matrix: $ M_1 \in \mathbb{R}^{13 \times 2} $
# 2.   **Hidden Layer**:
#   - Retrieved from 1st hidden layer, we have a 13-dimensional input vector.
#   - These will be again passed from this(2nd) hidden layer.
#   - Weight matrix: $ M_2 \in \mathbb{R}^{13 \times 13} $
# 3.   **Hidden Layer:**
#   - Again, we have a 13-dimensional input vector.
#   - These will be again passed from this(3rd) hidden layer.
#   - Weight matrix: $ M_3 \in \mathbb{R}^{13 \times 13} $
# 4.   **Output Layer:**
#   - Again, we have a 13-dimensional input vector.
#   - Since our last layer has 3 neurons, resulting matrix will be 3 dimensional.
#   - Output matrix: $ M_4 \in \mathbb{R}^{3 \times 13} $
# ---
#
# #### 3.
#
# * The formula for average surprisal:
# $$
# \text{Avg-Surprisal}_{LM}(w_{1:n}) = -\frac{1}{n} \log P_{LM}(w_{1:n})
# $$
#
# * Token probabilities: `p = [0.67, 0.91, 0.83, 0.40, 0.29, 0.58, 0.75]`
# * Applying the chain rule of probabilities, we get:
#
# $$
# P_{LM}(w_{1:n}) = 0.67 × 0.91 × 0.83 × 0.40 × 0.29 × 0.58 × 0.75 ≃ 0.255
# $$
#
# * Taking the logarithm of the value:
# $ \log(P_{LM}) = \log(0.255) ≃ -0.593  $
# * Multiplied by normalization factor (since we have 7 tokens , n=7), we get:
#
# $$
# \text{Avg-Surprisal} = -\frac{1}{7}(-0.593)  ≃ 0.0847
# $$

# %% [markdown]
# ## Exercise 2: Understanding LLM configuration (8 points)
#
# For this task, your job is to understand the configrations of a state-of-the-art transformer, provided in a `config.json` file for allowing to initialize a transformer through the function `AutoModelForCausalLM.from_pretrained()` witin the `transformers` library. This file contains meta-information about the parameter configurations of the transformer.
#
# Your task is to:
# 1. explain what each line of the following config provides. Please write a commend above the line explaining what the following parameter is.
# 2. modify the config so that the transformer would use a context window size of 1024, 12 attention heads, and a ReLU activation function.

# %%
{
  ## (`bool`, *optional*) — Whether to use a bias in the query, key, value and output projection layers during self-attention.
  "attention_bias": false,
  ##  (`float`, *optional*) — The dropout ratio for the attention probabilities.
  "attention_dropout": 0.0,
  ## (int, optional) — The id of the beginning-of-stream token.
  "bos_token_id": 100257,
  ##(int, optional) — The id of the end-of-stream token.
  "eos_token_id": 100257,
  ## (`str` or `function`, *optional*) — The non-linear activation function (function or string) in the decoder.
  # If string, `"gelu"`, `"relu"`, `"selu"` and `"gelu_new"`  are supported.
  "hidden_act": "relu",
  ## (int) — The hidden size of the model.
  "hidden_size": 5120,
  ## (`float`, *optional*) — The standard deviation of the truncated_normal_initializer for initializing all weight matrices.
  "initializer_range": 0.02,
  ## (`int`, *optional*) — Dimension of the MLP representations.
  "intermediate_size": 27648,
  ## (`int`, *optional*) —The maximum sequence length that this model might ever be used with.(Context window size)
  "max_position_embeddings": 1024,
  ## (`int`, *optional*) — The number of attention heads used in the multi-head attention layers of the model.
  "num_attention_heads": 12,
  ## (int) — The number of blocks in the model.
  "num_hidden_layers": 64,
  ## (`int`, *optional*) — This is the number of key_value heads that should be used to implement Grouped Query Attention.
  "num_key_value_heads": 8,
  ## (int, optional) — The id of the padding token.
  "pad_token_id": 100277,
  ## (`float`, *optional*) — The epsilon used by the rms normalization layers.
  "rms_norm_eps": 1e-06,
  ## (`Dict`, *optional*) — Whether to enable or disable RoPE scaling. (RoPE scaling can be used to increase the sequence length of the model during the inference time without necessarily fine-tuning it.)
  "rope_scaling": null,
  ## (`float`, *optional*) — The base period of the RoPE embeddings.
  "rope_theta": 500000,
  ##(bool, optional) — Whether the model’s input and output word embeddings should be tied.
  ## Note that this is only relevant if the model has a output word embedding layer.
  "tie_word_embeddings": false,
  ##(str, optional) — The dtype of the weights. This attribute can be used to initialize the model to a non-default dtype
  ##(which is normally float32) and thus allow for optimal storage allocation.
  "torch_dtype": "float32",
  ## (`bool`, *optional*) — Whether or not the model should return the last key/values attentions (not used by all models)
  "use_cache": true,
  ### (int) — The number of tokens in the vocabulary, which is also the first dimension of the embeddings matrix.
  "vocab_size": 100352
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c3bcfb17aab> in <cell line: 0>()
#       1 {
#       2   ## (`bool`, *optional*) — Whether to use a bias in the query, key, value and output projection layers during self-attention.
# ----> 3   "attention_bias": false,
#       4   ##  (`float`, *optional*) — The dropout ratio for the attention probabilities.
#       5   "attention_dropout": 0.0,
#
# NameError: name 'false' is not defined

# %% [markdown]
# ## Exercise 3 (15 points):
#
# In the lecture, we have extensively covered a core component of the transformer -- the self-attention calculation in the forward pass.
# In this exercise, your task is to perform the forward pass steps 1-6.i (i.e., up to, excluding, the forward step) from the exercise sheet assuming that the transformer has *a second* attention heads, where the second attention head has the following weight matrices:

# %%
Q_2 = [[0.5, 1, 1], [2, 0, 0.2], [3, 2, 0]]
K_2 = [[0.1, 0.5, 1], [0.5, 1, 1], [2, 2, 2]]
V_2 = [[1, 0.1, 0.3], [0, 3, 0.5], [1, 1, 1]]

# %% [markdown]
# Your task is to submit a solution calculating the contextualized representations of this second attention head.
# Please make sure to include all the intermediate calculation steps and answer the following question:
# - How does the memory load of running inference with the transformer scale with the number of attention heads?
#
# You can submit a picture / scan of a hand-written, or type it in TeX -- up to you.
#
# ### ***The solution is in the zip file***

# %% [markdown]
# ## Exercise 4: Fine-tuning Pythia for Question Answering (23 points)
#
# The learning goal of this exercise is to practice fine-tuning a pretrained LM, Pythia-160M, for a particular task, namely commonsense question answering (QA). We will use a task-specific dataset, [CommonsenseQA](https://huggingface.co/datasets/tau/commonsense_qa), that was introduced by [Talmor et al. (2018)](https://arxiv.org/abs/1811.00937). We will evaluate the performance of the model on our test split of the dataset over training to monitor whether the model's performance is improving and compare the performance of the base pretrained Pythia model and the fine-tuned model. We will need to perform the following steps:
#
# 1. Prepare data according to steps described in [sheet 1.1](https://cogsciprag.github.io/Understanding-LLMs-course/tutorials/01-introduction.html#main-training-data-processing-steps)
#    1. additionally to these steps, prepare a custom Dataset (like in [sheet 2.3](https://cogsciprag.github.io/Understanding-LLMs-course/tutorials/02c-MLP-pytorch.html#preparing-the-training-data)) that massages the dataset from the format that it is shipped in on HuggingFace into strings that can be used for training. Some of the procesing steps will happen in the Dataset.
# 2. Load the pretrained Pythia-160m model
# 3. Set up training pipeline according to steps described in [sheet 2.5]()
# 4. Run the training for **200 steps**, while tracking the losses. This number of steps should be sufficient for being able to tell that your training is working *in principle*.
# 5. Save plot of losses for submission

# %% [markdown]
# Your tasks:
# > 1. [19pts] Complete the code in the spots where there is a comment "#### YOUR CODE HERE ####". There are instructions in the comments as to what the code should implement. With you completed code, you should be able to let the training run without errors. Note that the point of the exercise is the implementation; we should not necessarily expect great performance of the fine-tuned model (and the actual performance will *not* be graded). Often there are several correct ways of implementing something. Anything that is correct will be accepted.
# > 2. [4pts] Answer questions at the end of the execise.

# %%
# !pip install torch transformers datasets langchain-community langchain_nvidia_ai_endpoints==0.3.9 python-dotenv==1.1.0 torchrl llama-index bertviz wikipedia
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.23-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain_nvidia_ai_endpoints==0.3.9
#   Downloading langchain_nvidia_ai_endpoints-0.3.9-py3-none-any.whl.metadata (11 kB)
# Collecting python-dotenv==1.1.0
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting torchrl
#   Downloading torchrl-0.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.2 MB/s eta 0:00:00
# Collecting llama-index
#   Downloading llama_index-0.12.35-py3-none-any.whl.metadata (12 kB)
# Collecting bertviz
#   Downloading bertviz-1.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from langchain_nvidia_ai_endpoints==0.3.9) (3.11.15)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain_nvidia_ai_endpoints==0.3.9) (0.3.56)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.39)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from torchrl) (3.1.1)
# Collecting tensordict<0.9.0,>=0.8.1 (from torchrl)
#   Downloading tensordict-0.8.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting llama-index-agent-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.7-py3-none-any.whl.metadata (438 bytes)
# Collecting llama-index-cli<0.5,>=0.4.1 (from llama-index)
#   Downloading llama_index_cli-0.4.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.13,>=0.12.35 (from llama-index)
#   Downloading llama_index_core-0.12.35-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.11-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-llms-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.3.38-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Collecting boto3 (from bertviz)
#   Downloading boto3-1.38.13-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from bertviz) (0.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (4.13.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints==0.3.9) (1.20.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints==0.3.9) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.76.2)
# Collecting aiosqlite (from llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting banks<3,>=2.0.0 (from llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading banks-2.1.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.2.18)
# Collecting dirtyjson<2,>=1.0.8 (from llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2,>=1.2.0 (from llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.6.0)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (11.2.1)
# Collecting tiktoken>=0.7.0 (from llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.17.2)
# Collecting llama-cloud<0.2.0,>=0.1.13 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.21-py3-none-any.whl.metadata (1.2 kB)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (2.7)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.6.22-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from tensordict<0.9.0,>=0.8.1->torchrl) (8.7.0)
# Collecting botocore<1.39.0,>=1.38.13 (from boto3->bertviz)
#   Downloading botocore-1.38.13-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->bertviz)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3->bertviz)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Collecting griffe (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading griffe-1.7.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (4.3.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints==0.3.9) (3.0.0)
# Collecting llama-cloud-services>=0.6.22 (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_cloud_services-0.6.22-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (2.33.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->tensordict<0.9.0,>=0.8.1->torchrl) (3.21.0)
# Collecting llama-cloud<0.2.0,>=0.1.13 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.19-py3-none-any.whl.metadata (902 bytes)
# Collecting colorama>=0.4 (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading langchain_nvidia_ai_endpoints-0.3.9-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 45.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.9 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 33.8 MB/s eta 0:00:00
# Downloading langchain_community-0.3.23-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 86.7 MB/s eta 0:00:00
# Downloading torchrl-0.8.0-cp311-cp311-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.7 MB/s eta 0:00:00
# Downloading llama_index-0.12.35-py3-none-any.whl (7.0 kB)
# Downloading bertviz-1.4.0-py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 13.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.0 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading llama_index_agent_openai-0.4.7-py3-none-any.whl (14 kB)
# Downloading llama_index_cli-0.4.1-py3-none-any.whl (28 kB)
# Downloading llama_index_core-0.12.35-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.6 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.11-py3-none-any.whl (14 kB)
# Downloading llama_index_llms_openai-0.3.38-py3-none-any.whl (23 kB)
# Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.4.7-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.4 MB/s eta 0:00:00
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.7 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.2 MB/s eta 0:00:00
# Downloading tensordict-0.8.2-cp311-cp311-manylinux_2_28_x86_64.whl (414 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.3/414.3 kB 29.1 MB/s eta 0:00:00
# Downloading boto3-1.38.13-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.8 MB/s eta 0:00:00
# Downloading banks-2.1.2-py3-none-any.whl (28 kB)
# Downloading botocore-1.38.13-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 78.4 MB/s eta 0:00:00
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading llama_parse-0.6.22-py3-none-any.whl (4.9 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 14.3 MB/s eta 0:00:00
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.5 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.8 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading llama_cloud_services-0.6.22-py3-none-any.whl (37 kB)
# Downloading llama_cloud-0.1.19-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.6/263.6 kB 18.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading griffe-1.7.3-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 10.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=095b200cf72d0c4525b9ee720c19e915f4a979862390a4a13cd08b87f9468580
#   Stored in directory: /root/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# Installing collected packages: striprtf, filetype, dirtyjson, xxhash, python-dotenv, pypdf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, jmespath, httpx-sse, fsspec, dill, colorama, aiosqlite, wikipedia, typing-inspect, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, griffe, botocore, s3transfer, pydantic-settings, nvidia-cusolver-cu12, llama-cloud, dataclasses-json, banks, llama-index-core, datasets, boto3, tensordict, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-cloud-services, langchain_nvidia_ai_endpoints, bertviz, torchrl, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, langchain-community, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed aiosqlite-0.21.0 banks-2.1.2 bertviz-1.4.0 boto3-1.38.13 botocore-1.38.13 colorama-0.4.6 dataclasses-json-0.6.7 datasets-3.6.0 dill-0.3.8 dirtyjson-1.0.8 filetype-1.2.0 fsspec-2025.3.0 griffe-1.7.3 httpx-sse-0.4.0 jmespath-1.0.1 langchain-community-0.3.23 langchain_nvidia_ai_endpoints-0.3.9 llama-cloud-0.1.19 llama-cloud-services-0.6.22 llama-index-0.12.35 llama-index-agent-openai-0.4.7 llama-index-cli-0.4.1 llama-index-core-0.12.35 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.6.11 llama-index-llms-openai-0.3.38 llama-index-multi-modal-llms-openai-0.4.3 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.7 llama-index-readers-llama-parse-0.4.0 llama-parse-0.6.22 marshmallow-3.26.1 multiprocess-0.70.16 mypy-extensions-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydantic-settings-2.9.1 pypdf-5.4.0 python-dotenv-1.1.0 s3transfer-0.12.0 striprtf-0.0.26 tensordict-0.8.2 tiktoken-0.9.0 torchrl-0.8.0 typing-inspect-0.9.0 wikipedia-1.4.0 xxhash-3.5.0

# %%
# note: if you are on Colab, you might need to install some requirements
# as we did in Sheet 1.1. Otherwise, don't forget to activate your local environment

from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, GPT2Tokenizer, GPT2LMHeadModel, DataCollatorForLanguageModeling
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# additioanlly, we need to install accelerate
# uncomment and run the following line on Colab or in your environment
# !pip install accelerate
# NOTE: in a notebook, reloading of the kernel might be required after installation if you get dependency errors with the transformers package
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)

# %%
### 1. Prepare data with data prepping steps from sheet 1.1

# a. Acquiring data
# b. (minimally) exploring dataset
# c. cleaning / wrangling data (combines step 4 from sheet 1.1 and step 1.1 above)
# d. splitting data into training and validation set (we will not do any hyperparameter tuning)
# (we don't need further training set wrangling)
# e. tokenizing data and making sure it can be batched (i.e., conversted into 2d tensors)
# this will also happen in our custom Dataset class (common practice when working with text data)

# %%
# downaload dataset from HF
# a. Acquiring data
dataset = load_dataset("tau/commonsense_qa")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/7.39k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/160k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/151k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1221 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1140 [00:00<?, ? examples/s]

# %%
# b. (minimally) exploring dataset
# inspect dataset
print(dataset.keys())

# print samples from the dataset
print(dataset['train'][:1])
print(dataset['validation'][:1])
print(dataset['test'][:1])

print(dataset['train'].column_names)
ds_size_tr = len(dataset['train'])
print(f"Train dataset size: {ds_size_tr}")
ds_size_val = len(dataset['validation'])
print(f"Validation dataset size: {ds_size_val}")
ds_size_test= len(dataset['test'])
print(f"Test dataset size: {ds_size_test}")

# plot dataset splits
labels = ['Train', 'Validation', 'Test']
sizes = [ds_size_tr, ds_size_val, ds_size_test]

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.show()


## Count question concepts manually
concept_freq = {}

# Collect concepts from each split
concepts_train = dataset['train']['question_concept']
concepts_val = dataset['validation']['question_concept']
concepts_test = dataset['test']['question_concept']

# combine all splits
all_concepts = concepts_train + concepts_val + concepts_test

# get question concept frequencies
for concept in all_concepts:
    if concept in concept_freq:
        concept_freq[concept] += 1
    else:
        concept_freq[concept] = 1

sorted_concepts = sorted(concept_freq.items(), key=lambda x: x[1], reverse=True)[:20]
concepts, counts = zip(*sorted_concepts)

# plot the top 20 most common question concepts in dataset
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(concepts, counts)
plt.xticks(rotation=45, ha='right')
plt.xlabel("Question Concept")
plt.tight_layout()
plt.show()
# Out:
# dict_keys(['train', 'validation', 'test'])
# {'id': ['075e483d21c29a511267ef62bedc0461'], 'question': ['The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?'], 'question_concept': ['punishing'], 'choices': [{'label': ['A', 'B', 'C', 'D', 'E'], 'text': ['ignore', 'enforce', 'authoritarian', 'yell at', 'avoid']}], 'answerKey': ['A']}
# {'id': ['1afa02df02c908a558b4036e80242fac'], 'question': ['A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?'], 'question_concept': ['revolving door'], 'choices': [{'label': ['A', 'B', 'C', 'D', 'E'], 'text': ['bank', 'library', 'department store', 'mall', 'new york']}], 'answerKey': ['A']}
# {'id': ['90b30172e645ff91f7171a048582eb8b'], 'question': ['The townhouse was a hard sell for the realtor, it was right next to a high rise what?'], 'question_concept': ['townhouse'], 'choices': [{'label': ['A', 'B', 'C', 'D', 'E'], 'text': ['suburban development', 'apartment building', 'bus stop', 'michigan', 'suburbs']}], 'answerKey': ['']}
# ['id', 'question', 'question_concept', 'choices', 'answerKey']
# Train dataset size: 9741
# Validation dataset size: 1221
# Test dataset size: 1140

# %%
# c. cleaning / wrangling data (combines step 4 from sheet 1.1 and step 1.1 above)
def clean_data(example):
    """
    Remove non-alphabetic or non-space characters from a text.

    Args
    ----
    text: str
        Text to clean.

    Returns
    -------
    cleaned_text: str
        Cleaned text without non-alphabetic symbols.
    """
    cleaned_text = "".join(
        [char for char in example if char.isalpha() or char.isspace()]
    )
    return cleaned_text

# apply the preprocessing function to all tweets
cleaned_dataset = dataset['train'].map(
    lambda example: {
        "question": clean_data(example["question"])
    }
)

# look at a few examples of clean tweets
print(cleaned_dataset[:1])
# Out:
# Map:   0%|          | 0/9741 [00:00<?, ? examples/s]
# {'id': ['075e483d21c29a511267ef62bedc0461'], 'question': ['The sanctions against the school were a punishing blow and they seemed to what the efforts the school had made to change'], 'question_concept': ['punishing'], 'choices': [{'label': ['A', 'B', 'C', 'D', 'E'], 'text': ['ignore', 'enforce', 'authoritarian', 'yell at', 'avoid']}], 'answerKey': ['A']}

# %% [markdown]
# Note that the test split provided with the dataset does not have ground truth answer labels. Therefore, we will only use the validation split to asssess the performance of our model.

# %%
# load tokenizer
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-160m")
tokenizer.pad_token = tokenizer.eos_token
# set padding side to be left because we are doing causal LM
tokenizer.padding_side = "left"
# Out:
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]

# %%
def massage_input_text(example):
    """
    Helper for converting input examples which have
    a separate qquestion, labels, answer options
    into a single string.

    Arguments
    ---------
    example: dict
        Sample input from the dataset which contains the
        question, answer labels (e.g. A, B, C, D),
        the answer options for the question, and which
        of the answers is correct.

    Returns
    -------
    input_text: str
        Formatted training text which contains the question,
        the forwatted answer options (e.g., 'A. <option 1> B. <option 2>' etc)
        and the ground truth answer.
    """
    # combine each label with its corresponding text
    answer_options_list = list(zip(
        example["choices"]["label"],
        example["choices"]["text"]
    ))

    # join each label and text with . and space
    answer_options =" ".join(
        [f"{label}.{text}" for label, text in answer_options_list]
    )


    # join the list of options with spaces into single string
    answer_options_string = "".join(
        [char for char in answer_options]
    )
    print(answer_options_string)

    # combine question and answer options
    input_text = example["question"] + " " + answer_options_string
    # append the true answer with a new line, "Answer: " and the label
    input_text += "\nAnswer: " + example["answerKey"]

    return input_text

# process input texts of train and validation sets
# Note : I think I got confused and also implemented a dataset cleaning cell above - Should I not have implement that?
massaged_datasets = dataset.map(
    lambda example: {
        "text": massage_input_text(example)
    }
)
# Out:
# Map:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Streaming output truncated to the last 5000 lines.
# A.solution to problem B.gaining knowledge C.know how to act D.understanding of E.being able to use
# A.optometrist B.dentist's office C.drug store D.bathroom E.bottle
# A.bland B.predictable C.known about D.boring E.send flowers
# A.music shop B.laboratory C.case D.operating room E.shed
# A.cupboard B.pantry C.shelf D.cabinet E.drower
# A.gripping B.briefcase C.carry object D.frying pan E.coffee cup
# A.office B.hospital C.friend's house D.hotel E.every u.s
# A.going to jail B.punishment C.recognizes their true oppressors D.death of E.dies
# A.admire B.cherish C.marry D.honor E.love
# A.desk B.exhibition hall C.own bedroom D.house E.office building
# A.school B.notebook C.book store D.office E.office supply store
# A.headache B.advance C.gain knowledge D.form opinions E.elation
# A.hotel B.train station C.opera house D.end of line E.city
# A.train B.wedding C.hotel D.amusement park E.entertainment
# A.defecating B.feces C.get tired D.gaining weight E.slacking
# A.big city B.chicago C.large city D.in the sky E.new york city
# A.people will understand B.embarassment C.children will learn D.teaching E.helping
# A.relaxation B.adventure C.headache D.deciding E.revelations
# A.schizophrenia B.restricted C.headache D.have no home E.shameful
# A.attic B.supermarket C.farmer's market D.refrigerator E.cellar
# A.cheeks B.parents C.common sense D.muscles E.feelings
# A.roof B.tree C.ground D.forest E.fall season
# A.reverence B.respect C.honor D.admiration E.kindness
# A.supermarket B.dick C.bedroom D.medicine chest E.bed
# A.quake 2 B.arsenal C.in a D.armory E.military service
# A.find truth B.examine thing C.go to market D.attend school E.cooking
# A.water lawn B.water plants C.plant trees D.garden roses E.playing on ground
# A.do up B.tie up C.zip up D.pick up E.button up
# A.maine B.india C.oregon D.washington state E.detroit
# A.enlightenment B.confusion C.understanding D.cynicism E.sadness
# A.supermarket B.recycling center C.backpack D.refrigerator E.house
# A.back alley B.shoe store C.storage area D.storage E.warehouse
# A.wedding B.bus stop C.crowd D.convention E.supermarket
# A.power B.influence C.win elections D.re elected E.bribe
# A.flushed B.flush C.refill D.clear E.smell bad
# A.sun B.chase C.dog show D.fair E.game
# A.problems B.inspiration C.crying D.knowledge E.trauma
# A.fun B.strategic C.made D.have fun E.satisfaction
# A.pantry B.cupboard C.cupboard D.supermarket E.jar
# A.laughter B.discomfort C.glee D.fun E.inspiration
# A.sore throat B.gossip C.conversation D.communication E.dry mouth
# A.in charge of project B.conquer opponent C.go to school D.begin work E.webisode
# A.collapse B.sweat C.drink water D.rest E.pace yourself
# A.madagascar B.rain forest C.captivity D.on a tree E.french government
# A.seeing artifacts B.shock C.crowds D.peace E.being bored
# A.arousal B.disease C.sweet D.halatosis E.cooties
# A.field B.bridge C.bottom of sea D.street E.wall
# A.store B.record C.musical D.jukebox E.napster
# A.japan B.desert C.town D.united states E.texas
# A.telephone book B.mathematics C.telephone D.roulette wheel E.math problem
# A.boredom B.enjoy C.moving D.fatigue E.injuries
# A.england B.police station C.airport D.travel agency E.city
# A.express yourself B.create art C.sew D.write E.express
# A.universe B.thought C.cake slices D.countries E.messed up
# A.airport B.come home C.train station D.taxi station E.bus depot
# A.circumspect B.immaturity C.discreet D.reasonable E.prudent
# A.gaining weight B.gas C.getting full D.satisfaction E.discomfort
# A.printed matter B.use paper C.michigan D.noise E.queue
# A.making money B.grand opening C.wealth D.lose money E.get rich
# A.air B.night or day C.weather report D.atmosphere E.above rain
# A.relaxation B.sweating C.shivering D.palpitate E.chills
# A.canada B.american southwest C.state fair D.central park E.texas
# A.pain B.small cuts C.competition D.injury E.puncture wound
# A.hands B.the table C.breaking D.coaster E.skill
# A.house B.bar C.pantry D.supermarket E.motherboard
# A.too many moms B.acting C.got injured D.distraught E.hurt
# A.uncertainty B.relax C.satisfaction D.compromises E.finished
# A.practise B.relaxing C.romantic D.take lessons E.tune
# A.mountains B.new york C.the surface D.michigan E.countryside
# A.linen cupboard B.allen key C.linen closet D.bedroom E.coverning pillow
# A.have experiences B.pollution C.happiness D.garbage E.death
# A.sanctuary B.church C.drugstore D.supermarket E.department store
# A.juice B.door C.shed D.supermarket E.cabinet
# A.sleep B.sit down C.sit on chair D.have rest E.lie on floor
# A.palace B.school C.person D.yoda E.house
# A.earth B.multivitamin C.mineral D.ore E.dietary concerns
# A.bleeding B.have fun C.relaxation D.carpal tunnel syndrome E.sore hands
# A.office supply store B.walmart C.classroom D.neighbor's house E.desk drawer
# A.healthy B.prepare C.nutrition D.clean E.open mouth
# A.confirmation B.celebrating C.pride D.recognition E.happiness
# A.understand B.able to hear C.pay attention D.very quiet E.shut up
# A.being satisfied B.heartburn C.weight gain D.overeating E.gain energy
# A.good feeling B.relief C.feel safer D.sense of peace E.wasted time
# A.province B.plebian C.workplace D.detroit E.construction business
# A.use of water B.drowning C.rash D.wet skin E.dry skin
# A.paint B.bed C.bureau D.suitcase E.sporting goods store
# A.movie B.theatre C.gymnasium D.circus E.concert hall
# A.cleanliness B.other people C.dry skin D.use soap E.nudity
# A.table B.backpack C.shelf D.floor E.cabinet
# A.surface of earth B.ground C.quary D.countryside E.mountain range
# A.learning B.embarrassment C.empathy D.fatigue E.anxiety
# A.bathroom B.cellar C.countryside D.restaurant E.plate
# A.demotion B.push down C.go off strike D.lower E.go off strike
# A.having fun B.fly to the moon C.may fall D.can fall E.get cold
# A.blunt B.ocean C.flat D.unobservant E.dim
# A.chesapeake bay B.underpants C.seychelles D.fishing boat E.cooking pot
# A.department store B.gas station C.grocery store D.drugstore E.supermarket
# A.belong to B.burn down C.winter storm D.her favorite E.face street
# A.arm B.person's head C.floor D.sink E.moustache
# A.australian outback B.bamboo grove C.wilderness D.island E.child's book
# A.pocket B.ashtray C.slot machine D.floor E.coin collection
# A.killing B.dread C.dying D.fear E.regret
# A.fun B.keep score C.try to win D.attempt to win E.bored
# A.in wild B.north america C.colorado D.hide E.tree
# A.response time B.miss work C.latency D.not awake E.loss of consciousness
# A.swimming pool B.lower person C.boat D.backpack E.lay down
# A.true B.important C.significant D.fundamental E.radical
# A.earth B.country C.pack D.organization E.army
# A.inspiration B.itchiness C.enjoyment D.boredom E.sore feet
# A.domestic B.local person C.indigenous D.normal E.native
# A.england B.iowa C.street corner D.city E.town
# A.hangover B.getting drunk C.swallow D.euphoria E.loss of control
# A.ticket booth B.at hotel C.shop D.bookstore E.post office
# A.office supply store B.office drawer C.desk drawer D.case E.school
# A.prosecution B.fear C.distress D.marriage E.misery
# A.fart B.meet C.get lost D.arrive there E.go back
# A.learn new B.think about C.ball stopped D.come to conclusion E.look at
# A.hear news B.attend school C.examine thing D.go to work E.go to market
# A.contact lens B.hardware store C.artificial breasts D.tube E.home
# A.drive in movie B.monitor C.movies D.home E.theatre
# A.american forest B.african desert C.northern hemisphere D.switzerland E.northern climates
# A.bank B.office building C.playing D.dividing work spaces E.work
# A.employment B.laid offf C.less sleep D.rejection E.income
# A.topfull B.incomplete C.enlarge D.close fitting E.partial
# A.casino B.show C.fairgrounds D.buy lottery E.friend's house
# A.suitcase B.garment bag C.drawer D.dirty laundry basket E.dresser
# A.enter college B.feel lonely C.cross street D.pass exams E.graduate from high school
# A.department store B.space shuttle C.new jersey D.office E.new orleans
# A.ridiculous B.anxiety C.open sores D.happiness E.different
# A.swear B.question C.swear D.wrong E.problem
# A.cast shadow B.fall down C.target D.weather storm E.face north
# A.cabinet B.restaurant C.apartment D.dishwasher E.washing machine
# A.happiness for B.give up C.acceptance D.cultural revolution E.new laws
# A.share files B.cost money C.multitask D.do work E.do arithmetic
# A.tropical forest B.ball stopped C.bedroom D.basement E.oklahoma
# A.road B.back yard C.neighbor's house D.porch E.farmyard
# A.chef B.abc book C.high school band D.orchestra E.museum
# A.understood B.being slapped C.people will understand D.pain E.creation of art
# A.in motion B.sleeping C.using energy D.action E.rapidly
# A.time passes B.fall asleep C.going to sleep D.lying down E.snore
# A.shopping center B.airport C.circus D.town E.city
# A.own home B.grocery store C.boat D.carpet E.lumberyard
# A.magazine B.case C.concert hall D.movie E.orchestra
# A.generous B.mean cruel C.nice D.friendly E.kindness
# A.working B.fix it C.accelerate D.putting together E.breakdance
# A.lake B.harbor C.sailing D.water E.ocean
# A.like B.problem C.harmony D.peace E.joyful
# A.broom closet B.old houses C.carpentry shop D.old clock E.put a bar
# A.being understood B.hug C.rambling D.kiss E.visiting friends
# A.walked B.guard house C.affection D.roll over E.go outside
# A.laughter B.exchanging information C.hope D.feel close to E.social approval
# A.airport B.hijack planes C.prison D.hotel E.afghanistan
# A.do mathematics B.read book C.answer question D.learn language E.begin to study
# A.make breakfast B.light fire C.go swimming. D.pack or bag E.go hiking
# A.shop B.post office C.at hotel D.airport E.bookstore
# A.bus stop B.corner C.office D.park E.motel
# A.livingroom B.world C.washing machine D.fire E.cedar chest
# A.thread B.artscraft store C.sewing D.livingroom E.frame
# A.morgue B.hat shop C.human body D.submarine E.california
# A.sleepwalking B.die a terrible death C.confusion D.fear E.might awaken
# A.read book B.sleep C.travel D.play games E.go work
# A.parlor B.front porch C.rock concert D.old folks home E.child's room
# A.book B.store C.forest D.lake E.current
# A.building B.london C.michigan D.cobblestones E.paris
# A.ore B.badges C.instruments D.junkyard E.metalworks
# A.athletic club B.country club C.recreational center D.college campus E.zoo
# A.fairgrounds B.state park C.field D.soccer game E.playground
# A.branch out B.vocals C.pretend D.wear costume E.sing songs
# A.need space B.drink water C.canter D.trot E.carry riders
# A.australia B.movie C.japanese restaurant D.shore E.tank
# A.black market B.music store C.system D.cathedral E.human body
# A.source of income B.fair trial C.headache D.white teeth E.freedom
# A.bad B.insubstantial C.inconsequential D.lame E.dwarf
# A.injury B.coma C.death D.a blow E.falling down
# A.regard B.taking care C.consideration D.assumed E.notice
# A.effort B.exercise C.relaxing D.playing around E.activity
# A.house B.friend's house C.party D.hospital E.desktop
# A.end marriage B.loyalty C.fidelity D.faithfulness E.mean shooting
# A.eye strain B.visual C.laziness D.distracted E.entertained
# A.shopping center B.airport C.business district D.city E.swimming pool
# A.mexico B.ocean C.japan D.texas E.new york
# A.straightforth B.back and C.reverse D.forward E.backwards
# A.one room apartment B.livingroom C.spare room D.sitting room E.in a bathroom
# A.liquid B.store C.garage D.pantry E.gutter
# A.startled B.important C.funny D.shocked E.laughter
# A.linearity B.have to wait for C.long wait D.anger E.irritation
# A.being able to use B.know how to act C.full capacity D.solution to problem E.gaining knowledge
# A.rest area B.theater C.hockey game D.classroom E.opera
# A.stupidity B.detention C.much work D.boredom E.trouble
# A.wear bathing suit B.fun C.excercise D.cool down E.exercise
# A.rebel B.fail C.obey D.stumble E.believe in jesus christ
# A.tree B.garden C.meadow D.rock E.rug
# A.have tv B.distraction C.learn D.fall asleep E.sitting
# A.neighborhood B.suburbs C.countryside D.city E.subdivision
# A.laugh B.open doors C.eat meat D.lie down E.drink water
# A.carolina B.south C.united states D.south of virginia E.north of south carolina
# A.injury B.mistakes C.late D.pain E.beauty
# A.acknowledgment B.price C.fresh produce D.smooth skin E.good credit
# A.opera singers B.detroit C.court D.towns E.downtown area
# A.ground B.petri dish C.water D.lake E.toilet bowl
# A.countryside B.parade C.western movie D.movies E.rodeo
# A.having children B.feeling good C.overpopulation D.exhaustion E.reproduction
# A.haversack B.desk C.cabinet D.backpack E.house
# A.canada B.major cities C.africa D.united states E.atlas
# A.fights B.competitiveness C.having fun D.getting tired E.learning
# A.recorder B.tape C.i would write it on paper if possible.. D.documentation of facts E.spell checker
# A.universe B.dictionary C.global D.commercial E.countryside
# A.park B.fence C.ground D.vines E.full bloom
# A.wear contact lenses B.go to movies C.open eyes D.have eyes E.rent one
# A.keep secrets B.side with C.hang out D.lying E.talking about
# A.alienate B.gather information C.condemn or condone D.talk about them E.gather facts
# A.decay B.ruin C.throw away D.destroy E.waste
# A.in a ocean B.big city C.bums D.europe E.downtown area
# A.michigan B.car crash C.automobile accidents D.backache E.getting tired
# A.store B.supermarket C.jar D.container E.cabinet
# A.the ground B.outside C.park D.ground E.uzbekistan
# A.kitchen cupboard B.cabinet C.cruet D.teaspoon E.table setting
# A.lawn B.spain C.tv room D.versailles E.english countryhouse
# A.swamp B.perfume C.carafe D.fountain E.ocean
# A.between two legs B.house C.store called target D.school E.shopping cart
# A.softness B.plastic C.stone D.wooden E.toolbox
# A.wait for B.dress nice C.go for haircut D.bathe E.shave
# A.driveway B.gallbladder C.river bed D.quarry E.creek bed
# A.schizophrenia B.deception C.live in poverty D.bad feelings E.wealth
# A.music shop B.brass band C.horn D.high school band E.orchestra
# A.rome B.college town C.playing sports D.large city E.hold concert
# A.will have to wait B.daydreaming C.impatience D.angry E.become impatient
# A.game preserve B.intertidal zone C.atlantic ocean D.south pacific E.sea water
# A.aunts house B.aunt's house C.books D.most families E.older generation
# A.dry mouth B.whispering C.being heard D.eye contact E.not listening
# A.occident B.america C.southern hemisphere D.far E.western hemisphere
# A.fight B.shocked C.humor D.nervous E.frightened
# A.humiliate B.mortify C.demean D.demean E.shame
# A.live long B.sadness C.injury D.long life E.happiness
# A.body B.good health C.tent D.fruit E.people
# A.wrong house B.read a book C.watch television D.sun themselves E.set table
# A.calluses B.playing wrong note C.audition D.making music E.read music
# A.play cards B.surf net C.play chess D.play games E.watch film
# A.peacework B.war C.violent D.happened E.trying
# A.beauty B.prepare C.positive D.get E.looking pretty
# A.canada B.ground C.mountains D.surface of earth E.yukon
# A.milk machine B.farmyard C.countryside D.fairgrounds E.long horns
# A.wedding B.fraternity house C.friend's house D.school E.bar
# A.airport B.heaven C.detroit D.flight school E.airplane
# A.working ground B.quarry C.desert D.work area E.under ground
# A.church B.closet C.own house D.office building E.art gallery
# A.regret B.indoor plumbing C.feel special D.own house E.electricity
# A.science lab B.laboratory C.coat pocket D.the meeting room E.chemistry lab
# A.harsh B.crazy C.sensible D.abrasive E.hard
# A.drawer B.desk C.briefcase D.medium E.office supply store
# A.go to war B.pride C.higher taxes D.more responsibility E.not profitable
# A.mountain B.flat land C.flat ground D.won E.pit
# A.school B.space shuttle C.trunk D.stalk E.shop
# A.clothing stores B.scotland C.eddie bauer D.fabric store E.online
# A.office B.church C.bowling alley D.building E.playround
# A.happiness B.punishment C.anger D.tears E.suffering
# A.often ignored B.time to pass C.gain insight D.play by himself E.action
# A.manicure the lawn B.garden backyards C.water plants D.grow plants E.pick flowers
# A.bus terminal B.train C.automobile D.file cabinet E.house
# A.think B.work hard C.do about D.study E.patent
# A.country B.park C.town D.countryside E.near
# A.photosynthesis B.bloom C.have roots D.flower petals E.flower in spring time
# A.suitcase B.box C.sentence D.house E.paragraph
# A.suitcase B.department store C.purse D.mall E.backpack
# A.sadness B.decomposition C.laughter D.rebirth E.burial
# A.coffee shop B.fridge C.table D.library E.shelf
# A.own kitchen B.denny's restaurant C.dinner table D.kitchen cupboard E.cabinet
# A.using money B.feel better C.go broke D.steal E.losing money
# A.rigor mortis B.unable to work C.change color D.change of color E.would cease to exist
# A.inspiring B.like music C.be musician D.make music E.tune
# A.building B.dumpster C.attic D.warehouse E.michigan
# A.pride B.mess C.gratifying D.allergic reactions E.adept
# A.use heater B.sprint C.jog D.run fast E.compete
# A.alone B.story book C.herb garden D.great outdoors E.sky
# A.sing B.live life C.play games D.fiddle E.jump up and down
# A.outside B.television C.ground D.landfill E.trashcan
# A.eat whales for breakfast B.listen to music C.have friends D.hug E.eat trash
# A.straightforth B.reverse C.backwards D.back and E.race
# A.demonstration B.concert C.garage D.bus stop E.synagogue
# A.shuffle B.dancing about C.troubles D.square dancing E.discovery
# A.suburb B.gardening C.slip and slides D.grass E.neighborhood
# A.fiction B.old information C.fun D.documentary E.propaganda
# A.frustration B.working hard C.over time D.stress E.employment
# A.exhaustion B.tiredness C.sneezing D.order E.make money
# A.brains B.feelings C.brown hair D.drug problem E.radio
# A.wall in B.produce fruit C.fall down D.branch out E.die
# A.play games B.push ups C.play with toys D.hear stories E.throw things
# A.better fitness B.exhaustion C.shortness of breath D.lose weight E.blisters
# A.cabinet B.meeting C.office D.cupboard E.home
# A.wall in B.grow tall C.fire D.covered in snow E.burn
# A.form images B.tended C.hatred D.play tricks on E.form thought
# A.feeling happy B.get hungry C.learning D.grow up E.injury
# A.good to eat B.crisp C.grocery store D.good for E.farm
# A.cup chin B.hard C.articulate D.sign language E.cup water
# A.anything B.everywhere C.judge men D.give peace E.help people
# A.bowling alley B.soccer field C.sporting event D.sporting goods store E.cuddle
# A.dance together B.speak words C.fight D.own cars E.believe in god
# A.cause businesses to grow B.get C.lie D.buy food E.win
# A.impatience B.have fun C.boredom D.giving birth to frogs E.wisdom
# A.basement B.universe C.bedroom D.tropical jungle E.amazonia
# A.power mower B.boat C.refineries D.gas station E.oil rig
# A.train B.tropical seas C.weather report D.america E.caribbean
# A.prepare dinner B.evaluate progress C.include examples D.work in school E.prove their point
# A.that you B.walking C.stress D.spending money E.relax
# A.boy or girl B.learn to speak C.talk nonsense D.begin to talk E.ride the bike
# A.hall B.kitchen C.neighbor's house D.card room E.livingroom
# A.retirement community B.pool C.cabinet D.park E.library
# A.truthful B.not fib C.not lie D.sense of duty E.think
# A.understand details B.being able to use C.loss of money D.economic boom E.spending money
# A.window B.television program C.open plain D.great outdoors E.eastern hemisphere
# A.sign language B.soft C.cup water D.articulate E.throw lasers
# A.trumpet B.military base C.military band D.american army E.music store
# A.weakness B.play sports C.entropy D.mass E.matter
# A.produce food B.raise crops C.can produce D.grow corn E.plant seeds
# A.row about B.combination C.marry each other D.make sex E.communicate
# A.broom B.broom closet C.old clock D.hardware store E.old houses
# A.british columbia B.seychelles C.texas D.zimbabwe E.zambia
# A.panic B.deadlines C.accomplishing D.momentum E.sitting down
# A.outside B.alabama C.virginia D.cape cod E.fish market
# A.theater B.opera house C.concert D.new orleans E.michigan
# A.grow up B.become adult C.ask questions D.play games E.acting out
# A.climb B.play frisbee C.travel D.hike E.go somewhere
# A.use gas fire B.warm room C.gas or electric D.brown meat E.warm pot of beans
# A.grow up B.form opinions C.become adult D.set table E.gather flowers
# A.neighbor's house B.garage C.table D.military base E.fairgrounds
# A.roast B.baking food C.cool temperature D.heat E.bake
# A.finish college B.begin teaching C.write D.answer question E.solve equation
# A.subway station B.library C.super market D.county engineer's office E.a friend
# A.auditorium B.fairgrounds C.airport D.metro station E.amusement park
# A.bookstore B.supermarket C.toy store D.candy store E.shop
# A.connecticut B.eastern united states C.florida D.new york E.sea
# A.store B.rug C.room D.friend's house E.online
# A.soup B.ocean C.puddle D.chicken E.glass
# A.lose weight B.feel better C.arthritis D.sweating E.pressure
# A.play music B.include drummer C.record album D.blaring E.encore
# A.playground B.school C.at hotel D.theater E.convenience store
# A.freeway B.demonstration C.state park D.store E.corner of two streets
# A.think B.see work C.speak out D.listen E.talk to people
# A.cost money B.fall apart C.be demanding D.happen to E.go wrong
# A.excellent B.outstanding C.exceptional D.superior E.sufficient
# A.earn money B.make decisions C.have imagination D.create E.produce goods
# A.stopping B.standing still C.stay still D.stand still E.dancing
# A.root cellar B.underground cellar C.pantry D.casserole E.restaurants
# A.station B.electrical device C.battery D.initial E.transportation system
# A.military B.bridge of ship C.battleship D.basketball team E.cruise ship
# A.feel sad B.anger C.happiness D.arrested E.suffering
# A.shelf B.supermarket C.military base D.neighbor's house E.in the garage
# A.condom B.drug store C.health center D.vagina E.drawer
# A.nearest house B.school C.warm place D.surface of earth E.office block
# A.allergies B.boredom C.pride D.pain and suffering E.cleanliness
# A.annoy mom B.jazz band C.brass band D.punk rock E.marching band
# A.urban area B.busy C.airport D.boarding bus E.towns
# A.michigan B.concert hall C.irish bar D.create music E.music shop
# A.human B.conduct experiment C.specific D.if they are nice E.plant
# A.bridge B.mountain range C.mountains D.ground E.forest
# A.toronto B.manhattan C.san jose D.large city E.city underground
# A.europe B.industrial complex C.workers D.russia E.free trade zones
# A.shoe B.pocket C.suitcase D.barber shop E.medicine cabinet
# A.cabinet B.classroom C.shelf D.bookbag E.desktop
# A.fight disease B.lower cholesterol C.cargo D.measurements E.lower blood pressure
# A.smoke B.homework C.volunteer D.party E.hang out
# A.innovation B.visual C.falling asleep D.entertained E.conformity
# A.house B.boat C.washroom D.stairwell E.hospital
# A.pocket B.purse C.rug D.laundromat E.beach
# A.map B.device C.area D.almost anywhere E.location
# A.falling in love B.smile C.talking D.shake hands E.punch in the face
# A.own death B.die C.great sorrow D.fear E.banquet
# A.difficult B.harsh C.hard D.severe E.strict
# A.coaster B.skill C.hands D.chair E.careful
# A.action B.florida C.basketball court D.pocket E.purse
# A.buffalo B.fight for life C.leave home D.hunt for food E.eating
# A.promise to do B.go to a store C.step forward D.milk cow E.need food
# A.food B.getting full C.full stomach D.full belly E.stomach aches
# A.basement B.kitchen C.rooms D.den E.yard
# A.safe B.military C.airport D.runway E.department store
# A.food B.chipmunk C.rodent D.nuts E.rabbit
# A.roof B.house C.windowless room D.company E.office building
# A.oregon B.united states C.washington D.idaho E.british columbia
# A.bedsores B.lay down C.bed sores D.sleep in E.open the curtain
# A.get dirty B.organize C.sort D.take off E.soap
# A.eat food B.drink water C.burp D.choke E.vomit
# A.nature B.sun C.rain D.sky E.ground
# A.marina B.airport C.stairwell D.island E.ocean
# A.supermarket B.toilet C.pantry D.bar E.motherboard
# A.get laid B.acknowledgment C.accomplish goals D.marry E.talk about themselves
# A.jar B.hot dog C.hamburger D.fast food restaurant E.refrigerator
# A.feather B.peacock C.porcupine D.hedgehog E.calligraphy
# A.understood B.pleasure C.happy D.happiness E.victory in war
# A.pacific northwest B.river C.canada D.northern california E.washington state
# A.dumpster B.detroit C.garbage dump D.state park E.subway
# A.stage B.demonstration C.record sound D.parade E.conference
# A.have no home B.open sores C.enjoy D.different E.anxiety
# A.michigan B.apiary C.orchard D.bee hive E.united states
# A.wait turn B.pay C.frustration D.pain E.order
# A.street B.suburb C.city D.hospital E.town
# A.town B.office building C.patient D.medical center E.candy shop
# A.ship goods B.mail order C.own resources D.peddled E.branch out
# A.on purpose B.correction C.good D.correct answer E.success
# A.getting drunk B.food C.plan D.having fun E.meeting new people
# A.populated areas B.opera C.race track D.roadblock E.at the foot path
# A.stadium B.home C.auditorium D.arena E.opera house
# A.getting food B.wet clothes C.getting drunk D.catching fish E.wetness
# A.pride B.frustration C.emotions D.encouraging E.tensions
# A.die B.hibernate C.last 100 years D.spring forth E.cause death
# A.competent B.beneficial C.ugly D.excellent E.profitable
# A.large city B.london C.big city D.toronto E.chicago
# A.advertising company B.project C.new york D.city E.work
# A.distrust B.deception C.fooled D.play E.tag
# A.happiness B.feel guilty C.weight gain D.spills E.indigestion
# A.disneyland B.refrigerators C.shop D.obesity E.table
# A.deaths B.moving C.car wrecks D.using gas E.may die
# A.fair B.phone book C.city D.dental office E.las vegas
# A.ignore B.hinder C.giving trouble D.do nothing E.hurting
# A.bundle B.loft C.charming D.home depot E.house
# A.feeling better B.invigorating C.sleeping D.stress E.deep breathing
# A.music store B.bathroom C.post office D.craft store E.doctor's office
# A.candy store B.box C.drug store D.movies E.christmas stocking
# A.college B.living room C.house D.band E.music room
# A.being happy B.frustrated C.troubles D.discovery E.unpredictable
# A.dining room B.home C.hardware store D.closet E.computer
# A.unexpected B.habitual C.even D.expected E.common
# A.vacate B.vacationgoer C.include cruise D.racecation E.traveler
# A.secret passageway B.airport C.computer network D.freeway E.wires
# A.the house. B.disneyland C.bowling alley D.park E.sporting event
# A.ring B.jewelry store C.treasure chest D.fort knox E.church
# A.illiteracy B.watching tv C.acculturation D.at grade level E.illiterate
# A.doctor's office B.music store C.bathroom D.post office E.fish hatchery
# A.sweating B.have fun C.cheers D.dancing E.pain
# A.healthy children B.a car C.treated with respect D.easy life E.own house
# A.not die B.lay still C.stationary D.staying put E.be still
# A.spa B.at hotel C.motel room D.bath room E.locker room
# A.feeling good B.enjoyment C.agony D.pleasure E.feel good
# A.vehicle B.bus depot C.bus D.car E.train station
# A.put on shoes B.sit up C.thank god D.say love E.converse
# A.watch film B.play cards C.surf net D.talking on the phone E.see favorite show
# A.two arms B.live forever C.two eyes D.lay eggs E.ten fingers
# A.revelations B.thinking C.understanding D.action E.discovery
# A.desk B.grocery shop C.house D.antique store E.discount store
# A.choke B.give up C.live D.sigh E.cough
# A.landscape B.azawakh C.middle america D.georgia E.countryside
# A.burn B.changes color with seasons C.turn brown D.continue to grow E.eat water
# A.armored car B.battlefield C.war zone D.tavern E.white house
# A.disappointment B.new realization C.heat wave D.joy E.wanting more
# A.problems B.writing down C.being prepared D.phoning E.panicking
# A.garage B.tool kit C.toolbox D.tool shed E.hardware store
# A.reject B.annoy C.refuse D.stockpile E.detest
# A.street B.in the usa C.texas D.every city E.countryside
# A.golf course B.medical school C.emergency room D.nursing home E.relaxing
# A.helicopter B.war zone C.armored car D.white house E.battlefield
# A.subdivision B.neighborhood C.file D.city E.property
# A.subways B.desert C.mexico D.atlas E.developed land
# A.rebound B.underwear C.recoil D.stretch E.bounce
# A.footbed B.during the day C.awake D.sleep E.floor
# A.light fire B.stay in bed C.opposite of hot D.scream E.spit
# A.creation B.hatred C.paste D.soft copy E.unique
# A.street B.sewer C.landfile will not use for garbage D.landfile E.garbage dump
# A.embarrassment indictment B.tension C.going to jail D.penalty E.mistrial
# A.restrict freedom B.showing mercy C.send to room D.deny E.put in jail
# A.toy store B.fun C.street D.university E.garage
# A.indian ocean B.gulf of mexico C.pacific ocean D.atlantic ocean E.sea world
# A.having fun B.new contacts C.meet new people D.making new friends E.doing drugs
# A.medicine cabinet B.travel bag C.supermarket D.closet E.garbage
# A.waterfall B.shopping mall C.beach D.disneyland E.state park
# A.see exhibits B.design software C.read book D.use television E.eating dinner
# A.travel new places B.learn new C.learn to read D.enjoyable E.bored
# A.gain weight B.promise to do C.fear death D.cross street E.laws
# A.car dealership B.car show C.superb D.parking lot E.freeway
# A.send flowers B.sneaky C.singing D.hide from E.hiding
# A.introduce yourself B.greeting C.look over D.friendly E.high five
# A.library B.post office C.university D.technical store E.large city
# A.learn to fly B.spread wings C.fly north D.fly high E.head south
# A.having children B.feeling good C.food shortage D.exhaustion E.overpopulation
# A.her hair B.better circumstances C.people helped D.learning new skills E.happiness
# A.car crash B.stress C.death D.happiness E.transportation
# A.happiness for B.new laws C.protest D.change in leadership E.cultural revolution
# A.licking on floor B.frequent urination C.throwing up D.get pregnant E.toxicity
# A.eat eggs B.smoke pot C.believe in god D.make tools E.writing
# A.eat B.wash legs C.wash hands D.zip pants E.flush toilet
# A.peanut B.major city C.large city D.urban areas E.sports complex
# A.terrible B.go to prison C.getting in trouble D.screams E.mass hysteria
# A.health centre B.resort C.country club D.house E.golf club
# A.meditation B.nothing C.confused D.epilepsy E.meditate
# A.friend's house B.party C.dinner D.stadium E.water cooler
# A.appalachians B.north carolina C.virginia D.pennsylvania E.montana
# A.united states B.united states C.washington D.oregon E.british columbia
# A.cry B.listen to music C.tragic film D.take phone call E.get drunk
# A.fall down B.lie flat C.get down D.lay down E.sitting down
# A.sit comfortably B.think about things C.might understand D.enjoy E.brain work
# A.indoor plumbing B.feel special C.electricity D.headache E.forest
# A.growl B.drink water C.claw D.think E.purr
# A.football game B.hunger games C.family situation D.text book E.lawbook
# A.library B.express information C.music festival D.dance E.go somewhere
# A.you die B.obesity C.feeling satisfied D.feel full E.digestion
# A.cooking B.coffee C.food store D.cooking pot E.boiling
# A.rural area B.meadow C.forest side D.countryside E.forest
# A.legs ached B.have to say C.move around D.start walking E.fall down
# A.medicine cabinet B.shower C.shaving kit D.first aid kit E.the breadbox
# A.own house B.cotton candy C.kitchen D.english house E.meaningful work
# A.back pocket B.meeting C.street seller D.drug store E.school
# A.germany B.town C.rio de janeiro D.dance dance dance E.hotel
# A.cure bacterial infection B.medicine cabinet C.capsule D.prescribed E.pharmacy
# A.ballpark B.flower bed C.park D.backyard E.outdoors
# A.city hall B.anything C.fabric store D.physical world E.science lab
# A.cheese B.kitchen C.small hole D.department store E.garden
# A.attack B.run fast C.fleas D.defend E.eat
# A.office B.corner C.desktop D.corner of garden E.bedroom
# A.hardware store B.tool shed C.toolbox D.diy store E.tool kit
# A.backyard B.jungle C.outdoors D.flower bed E.park
# A.glasses B.nasal cavity C.tastebud D.inner ear E.retina
# A.sparse B.slim C.runny D.brainy E.obesity
# A.loss of control B.memory loss C.closed eyes D.confusion E.meditation epilepsy
# A.apartment B.livingroom C.bus stop D.den E.neighbor's house
# A.television show B.fish tank C.discount store D.desk drawer E.office building
# A.an mbe B.running C.winning D.have fun E.cheat
# A.relax B.can rest C.meditate D.fart E.drink
# A.glovebox B.drugstore C.purse D.on your head E.shirt pocket
# A.hungry B.peacefulness C.religious experience D.loss of balance E.sleepwalking
# A.multiplication B.putting together C.times D.subtraction E.multiply
# A.brass band B.music store C.home D.army corps E.american army
# A.cell phone B.have imagination C.day dream D.think E.have fun with
# A.office B.desk C.bedroom D.desktop E.corner
# A.result in getting killed B.protest C.being done against D.hockey game E.war
# A.outback B.neighbor's house C.waterfall D.gym E.at hotel
# A.lack of sleep B.twins C.venereal disease D.overpopulation E.children born
# A.plan to marry B.make sex C.communicate D.sleep in separate rooms E.dance
# A.frequent B.unpredictable C.short term D.time off work E.eternal
# A.getting tired B.illiteracy C.sitting down D.excitement E.procrastination
# A.zoo B.museum C.disneyland D.school E.toy store
# A.make money B.better comprehension C.amount to D.ask questions E.do well
# A.neck B.own brain C.human body D.torso E.heart
# A.theatre B.conference C.show films D.movies E.meeting
# A.sore muscles B.injury C.errors D.happiness E.sadness
# A.barbers B.messy C.beauty salon D.perfumery E.bathroom
# A.clothes B.laundry soap C.water and soap D.soap and water E.time
# A.grief B.bloody mess C.freedom D.sorrow E.death of
# A.outdoors B.forest C.valley D.nature E.countryside
# A.increase stamina B.get fitter C.eat healthy food D.too fat E.good health
# A.galaxy B.solar system C.universe D.sky E.space
# A.store B.transit C.sporting goods store D.locker room E.bus station
# A.person B.vein C.human body D.a cut E.needle
# A.magic B.outer space C.air D.universe E.night sky
# A.business B.mall C.store D.sell goods E.house
# A.jail B.love C.restaurant D.church E.homes
# A.backyard B.restaurant C.these twos places are  cannot be found .. D.barbeque E.neighbor's house
# A.forest B.library C.woods D.black lagoon E.zoo
# A.shake hands B.say hi C.greet D.say goodbye E.have coffee
# A.make art B.believe in god C.leave D.come home E.go out
# A.falling down B.coma C.dreaming D.death E.forgetfulness
# A.sick B.pain C.conclusion D.relief E.happiness
# A.make friends B.buy food C.share the wealth D.lie E.get
# A.building B.demonstration C.laugh D.garage E.conference
# A.drowning B.grass C.cactus D.surface of earth E.blizzard
# A.roof B.sky C.grieve D.poop E.molt
# A.get punished B.vengeance C.going to prison D.joy E.going to jail
# A.bus depot B.state park C.bus stop D.train station E.school
# A.capsulize idea B.train C.suck D.exception E.anarchy
# A.canteen B.asian countries C.england D.building E.london
# A.fall B.schizophrenia C.made fun of D.false information E.brain tumor
# A.apartment B.internet C.buildings D.neighbor's house E.end of line
# A.salad B.restaurant C.grocery store D.kitchen E.food store
# A.lowered B.stagnant C.stagnate D.hold up E.stopping
# A.windowsill B.sunbathers C.disneyland D.sea E.summer
# A.hear things B.stop speaking C.look at speaker D.you'll learn E.concentrate on sounds
# A.need to urinate B.vomiting C.having fun D.swallow E.sickness
# A.massachusetts B.connecticut C.new england D.new jersey E.west united states
# A.basement B.antarctic C.house D.cellar E.heat building
# A.horse B.cow C.bullbleep D.feeble E.female
# A.compost pile B.floor C.hostel D.milky way galaxy E.back alley
# A.park B.trees C.countryside D.forest E.outdoors
# A.sporting event B.hockey game C.living room D.soccer game E.football stadium
# A.cause fire B.short fuse C.power outage D.produce heat E.shock
# A.live life B.wait for C.emotion affection D.kiss E.entertain
# A.fun B.free C.very very nice D.expensive E.very important
# A.mouse trap B.sky C.disneyland D.filled with air E.fairgrounds
# A.marry B.dress himself C.drive train D.drive car E.ball stopped
# A.homework B.school grade C.practice D.ignore E.park
# A.downtown B.major city C.california D.stripmall E.tokio
# A.penalty B.arrest C.shame D.tension E.go to jail
# A.floor B.near end C.falling down D.entertainment E.end badly
# A.police officer's belt B.police station C.traffic D.war E.pants
# A.hardware store B.tool shed C.storage D.tool kit E.toolbox
# A.south africa B.tree tops C.zoos D.great outdoors E.tropical areas
# A.eat meat B.be excited C.need food D.annoy E.open doors
# A.factory B.there will be no food allowed in the theatre. C.transmission D.big city E.carnival
# A.examine thing B.use television C.design software D.use computer E.find truth
# A.coming together B.supper club C.mall D.cruise ship E.home
# A.judge B.conquer opponent C.advance into battle D.fight enemy E.dancing
# A.breathlessness B.shortness of breath C.calluses D.exercise E.increased heart rate
# A.bed B.couch C.bathroom D.school E.airport
# A.paralysis B.regret C.arrest D.nudity E.drunkenness
# A.in charge B.freedom C.rich person D.free person E.hired help
# A.microwave B.meat loaf C.outside D.backyard E.bedroom
# A.vessel B.rock band C.marching band D.music store E.symphony orchestra
# A.drawer B.kitchen cabinet C.china cabinet D.tea room E.tea cabinet
# A.socialize B.meet people C.make people laugh D.tell jokes E.meet friend
# A.hotel B.school C.society D.house E.harm's way
# A.headaches B.fun C.getting warm D.broken E.exercise
# A.meadow B.idaho C.rhode island D.garden E.park
# A.french door B.car door C.car door D.swing door E.exterior door
# A.disturbed B.stressed C.give up D.windy E.flustered
# A.hospital B.ghetto C.emergency kit D.controlling bleeding E.ambulance
# A.selling things B.gas C.feel resentful D.machine part E.cross street
# A.own home B.resteraunt C.restaurant D.hotel E.mansion
# A.texmex B.san diego C.southern california D.tijuana E.mexico
# A.contract B.retract C.compress D.hold E.shorten
# A.theater B.pocket C.supermarket D.sidewalk E.street
# A.south carolina B.new england C.a cruise ship. D.maine E.chesapeake bay
# A.crime scene B.backyard C.police station D.military base E.police car
# A.being dead B.misery C.kill yourself D.loss of someone E.scars
# A.death B.disorientation C.frequent urination D.having sex E.bad breath
# A.two arms B.drinks C.stupidity D.one body E.muscles
# A.fatigue B.maid C.headache D.arguments E.asthma
# A.freedom of expression B.freedom of information C.hugs D.own house E.food and water
# A.garden B.spain C.rice paddy D.house E.southern europe
# A.hardware store B.store room C.garage D.construction worker's vehicle E.tool shed
# A.one head B.two ears C.lay eggs D.3 legs E.two feet
# A.full bladder B.ticket C.alcoholism D.nausea E.breaking
# A.residential area B.suburbs C.outskirts of city D.surface of earth E.street
# A.being well B.wounds C.cause person to hoarse D.healthy E.healthiness
# A.funeral B.closet C.container D.trunk E.basement
# A.debt B.peace C.panic D.laugh E.having fun
# A.of states B.united states C.american state D.traffic E.california
# A.zoo B.soccer game C.classroom D.bathroom E.toy store
# A.university B.book C.field D.meeting E.class
# A.children's story B.forrest C.mulberry bush D.animated film E.outdoors
# A.cross street B.amount to nothing C.seek no help D.doctor himself E.visit relatives
# A.universe B.outer space C.sky D.milky way E.orbit
# A.wedding B.around dinner table C.supermarket D.dinner together E.park
# A.office B.motel C.desktop D.rest area E.neighbor's house
# A.finite B.over C.good D.important E.ending soon
# A.drawer B.holster C.crime scene D.police helicopter E.police station
# A.dry B.prolix C.loquacious D.verbose E.bombastic
# A.drink tea B.have to sleep C.eat food D.say hello E.need money
# A.mountain range B.countryside C.volcano D.ground E.bridge
# A.dryer B.roof C.swimming pool D.gym E.pants
# A.ruin B.shrinkage C.wear out D.wet clothes E.torn
# A.get full B.gaining weight C.gain weight D.calories E.stomach ache
# A.trees B.spout C.roof D.ground E.street
# A.hate each other B.welcome change C.make choice D.adapt E.talk to each other
# A.utah B.france C.chemotherapy D.rocky mountains E.british columbia
# A.change B.separate people C.stop people D.motivate E.confuse
# A.relaxation B.relaxation C.feeling better D.recuperation E.doing nothing
# A.hear testimony B.examine thing C.surf net D.browsing E.see exhibits
# A.study medicine B.care for patients C.provide care D.resuscitate E.perform a physical
# A.show time B.use calendar C.display time D.display position on map E.play music
# A.disneyland B.circus C.supermarket D.carnival E.state park
# A.polish your guitar regularly. B.pick C.practice D.have fun E.desire
# A.patience B.intention C.decision-making skills D.buying movie tickets E.basic organization
# A.being heard B.sore throats C.hoarse voice D.change in mood E.sad
# A.shattered B.recycled C.shatter D.tempered E.broken
# A.humiliation B.sweaty C.fatigue D.blisters E.exhaustion
# A.significant B.important C.radical D.radical E.essencial
# A.church B.concert C.opera D.bedroom E.restaurant
# A.near B.proximity C.closeness D.close E.duration
# A.war B.police station C.army bunker D.security personnel E.holster
# A.brown meat B.mexico C.open can D.bake bread E.warm food
# A.alaska B.hells canyon C.south lake tahoe D.central idaho E.canada
# A.inside tent B.delivery room C.hardware store D.backpack E.sporting goods store
# A.hazardous waste B.construction C.fabric store D.science lab E.house
# A.golf course B.front yard C.suburbia D.neighborhood E.michigan
# A.wilderness B.queensland C.great outdoors D.jungle E.austrailia
# A.obsolete B.addictive C.entertaining D.bycone E.legal
# A.shop B.grocery C.disneyland D.airport E.museum
# A.porch B.school C.jail D.rug E.library
# A.mexico B.texaphyrin C.united states D.southwest E.gulf states
# A.geometry B.circle C.town center D.fifties E.carpenter's tool box
# A.state facts B.teach pupils C.group students D.better knowledge E.dividing students
# A.experience pleasure B.laws C.value life D.thank god E.go into debt
# A.mouth B.jar C.fridge D.house E.plate
# A.fork in road B.town center C.city street D.cars E.street corner
# A.room B.store C.patio D.friend's house E.building
# A.cupboard B.everything C.own home D.stuff in home E.garbage dump
# A.fatigue B.addiction C.power gains D.entertainment E.headaches
# A.hundredweight B.upper C.hour D.quarterlight E.school year
# A.thank god B.wait in line C.volunteer D.offer help E.enjoy working
# A.feelings B.shrink C.free will D.muscles E.parents
# A.wall B.store C.computer network D.company E.airport
# A.dewey decimal system B.book C.library D.newspaper E.internet
# A.compromises B.eloping C.calmness D.fucking E.handshake
# A.closet B.trunk C.drawer D.suitcase E.washing machine
# A.change in leadership B.revolution C.no water D.acceptance E.depression
# A.smiled B.say love C.sit up D.cross street E.converse
# A.best things in life B.own house C.slim waist D.more weight E.comfortable shoes
# A.feel lumpy B.itches C.feel cold D.feel pressure E.feel clammy
# A.sahara B.disneyland C.seattle D.street E.forest
# A.country B.continent C.west virginia D.mountainous region E.mountainous area
# A.bliss B.hostility C.peace D.accidents E.find truth
# A.lobby B.office park C.at hotel D.cellphone E.motel
# A.luggage compartment B.airport C.room D.clothing store E.canada
# A.chicken coop B.law office C.dog house D.hollow log E.backyards
# A.attacked B.of hatred C.defend yourself D.get rid of E.being gay
# A.floor B.computer game C.art D.song E.roof
# A.delineating political unit B.sporting event C.society D.basketball E.basketball
# A.gymnasium B.soccer game C.sporting event D.pharmacy E.soccer game
# A.deep south B.united states C.gulf states D.swamp E.98 of world's crayfish
# A.go to bed B.become adult C.read book D.grow up E.clean room
# A.two ears B.paws C.one mouth D.big heart E.tail
# A.bathroom B.apartment C.stall D.hospital E.rest area
# A.cathedral B.bridge C.building D.ancient rome E.hole
# A.engine B.sewing shop C.hardware store D.sporting goods store E.fishing camp
# A.transistor B.vessel C.box D.pie E.seabase
# A.sea world B.tropical waters C.tomales bay D.aquarium E.great oceans
# A.newspaper B.desktop C.art show D.art museum E.table
# A.ground B.waterfall C.surface of earth D.museum E.atmosphere
# A.make wine B.shops C.deserts D.bowl of fruit E.sunshine
# A.coffeehouse B.coffee house C.laundry room D.cupboard E.game room
# A.ashtray B.pocket C.coin collection D.slot machine E.deposit box
# A.backyard B.relaxed position C.soft place D.alley E.urban settlement
# A.lower interest B.raising interest rates C.higher interest rates D.lowering prices E.save money
# A.internet cafe B.refrigerator C.teapot D.cupboard E.coffee shop
# A.florida B.canada C.in washington D.utah E.colorado
# A.garden B.bathroom C.classroom D.home E.university
# A.own cars B.dance together C.talk to each other D.speak words E.kissing one another
# A.school B.garage C.hand D.record player E.palm pilot
# A.locker room B.in the showers C.linen closet D.swimming pool E.cupboard
# A.pregnancy B.hungry C.insomnia D.sleeping in E.making love
# A.park B.train station C.movie theater D.subway E.auditorium
# A.grocery store B.drawer C.shelf D.supermarket E.shopping cart
# A.office supply store B.desk drawer C.schools D.under the arm E.pencil box
# A.electronic equipment B.screen C.electronic devices D.pc board E.electrical machine
# A.medium B.saltwater C.sea world D.atlantic ocean E.seawater
# A.law B.trial C.going to court D.hurt feelings E.bad feelings
# A.problem B.peace C.love D.contract E.like
# A.demonstration B.kitchen C.furniture store D.hallway E.apartment
# A.store B.bag C.drawer D.purse E.pant pocket
# A.argument B.tension C.anger D.happiness E.stress
# A.say'hi B.have sex C.conversation D.handshake E.train
# A.big city B.transmission C.classroom D.bowling alley E.in the front yard
# A.fridge B.oven C.supermarket D.kitchen E.table
# A.kill B.distress C.strangle D.die E.dead
# A.park B.fence C.ground D.backyard E.balcony
# A.exasperation B.change of heart C.scrutinizing D.boredom E.read
# A.choke B.getting full C.burp D.eat food E.regurgitating
# A.turn on B.play music C.eat cake D.space shuttle E.blaring
# A.laughter B.like C.masturbation D.joy E.erection
# A.park B.forest C.tree D.roof E.yard
# A.northern hemisphere B.atlantic ocean C.go boating D.england E.canada
# A.happiness B.fun C.entertainment D.love E.stupid
# A.good feeling B.conflict C.happiness D.having friends E.problems
# A.drinking B.enjoyment C.advantage D.intimacy E.happiness
# A.be still B.stay put C.stay still D.sit still E.standing still
# A.back yard B.hen house C.storybook D.natural habitat E.bathroom
# A.refrigerator B.cold weather C.microwave D.water cooler E.mixed drinks
# A.hedgerow B.temperate climate C.botanical gardens D.beehouse E.backyard
# A.desk drawer B.art room C.classroom D.bathroom E.school
# A.pick up B.use water C.use soap D.get dirty E.gather up
# A.adverse reaction B.teach C.friendship D.rumors spread E.increased understanding
# A.english carrier B.achromatic C.courageous D.bright E.fearless
# A.bar B.human being C.cemetary D.graveyard E.earth
# A.sadistic dentist's office B.atmosphere C.laboratory D.chemistry lab E.moon
# A.north america B.northern hemisphere C.western hemisphere D.magnets E.map
# A.egypt B.city C.open sea D.desert E.quarry
# A.banned B.underage C.black market D.illegal E.rules
# A.sporting event B.watch show C.show D.demonstration E.watch game
# A.garden B.grocery store C.closet D.restaurant E.mart
# A.know how to find B.work hard C.remember where D.reach for E.purchase
# A.open eyes B.get to sleep C.deep sleep D.sleep again E.conscious
# A.annoyance B.hospitalized C.schizophrenia D.broken heart E.stress
# A.pregnancy B.feeling refreshed C.mowing lawn D.might dream E.good sleep
# A.city B.amusement park C.parkade D.apartment complex E.people
# A.wash clothes B.wipe off C.clean clothing D.bathe E.clean clothes
# A.innocent until proven guilty B.different C.human D.hurt E.independent
# A.heart problems B.tiredness C.relaxation D.heart attacks E.good health
# A.expressive B.excited C.drunk D.headache E.eat every day
# A.dry hair B.blowing hard C.change direction D.dry skin E.cotton mouth
# A.tidepools B.fishing boat C.north sea D.gulf of mexico E.grocery store
# A.sit quietly B.concentrate C.wake up D.stay focused E.relax
# A.intelligent children B.have confidence C.acknowledgment D.wonderful memories E.know truth
# A.electric mixer B.electric hammer C.electrabus D.electric typewriter E.drum sander
# A.humans B.city C.movie theaters D.arena E.courthouse
# A.satisfaction B.happiness C.shopping D.paying bills E.spending money
# A.mexico B.magic C.hotel D.phone book E.motel
# A.rooster B.hen C.bought at store D.cow E.tuna
# A.bowl of fruit B.salad C.table D.food store E.restaurant
# A.bank B.wallet C.restaurant D.congress E.mail box
# A.say hello B.greet C.associate D.socialize E.smile
# A.laboratory B.state park C.fairgrounds D.the grocery store E.zoos
# ...
# A.forgetting B.brainless C.forgetfulness D.forgotten E.memory loss
# A.citrus B.band C.platoon D.orchestra E.acrobats
# A.laundromat B.bedroom C.shopping mall D.library E.thrift store
# A.hook up B.meet new people C.get drunk D.enjoy yourself E.having sex
# A.hotel room B.vets office C.doctor's office D.hospital E.school
# A.stock yard B.everything C.own home D.garbage dump E.cupboard
# A.vault B.department store C.suitcase D.handbag E.safe deposit box
# A.television B.drawer C.attic D.bed E.counter
# A.talking B.open mind C.falling in love D.common interests E.smiling
# A.under rocks B.grocery store C.post office D.fallen tree E.toenails
# A.one winner B.frustration C.encouraging D.emotions E.happiness
# A.beach B.destination C.charlie chaplin film D.seattle E.suitcase
# A.see exhibits B.watch film C.see particular program D.study film E.have conversation
# A.spa B.high school C.school or ymca D.college campus E.lunch
# A.imagination B.sand box C.water fountain D.dishwasher E.kitchen cabinet
# A.dehydration B.bone damage C.fall down D.breathing hard E.sweat
# A.foolishness B.loss of innocence C.cynicism D.open mind E.smartness
# A.watch television B.listen to radio C.open letter D.thank god E.say goodbye
# A.offer B.rejection C.income D.hope E.sandwich
# A.department store B.washing clothes C.kitchen cabinet D.homes E.hotel kitchen
# A.conference B.train station C.town D.internet E.apartment
# A.communication B.waving hands C.revelation D.listening to E.distraction
# A.courthouse B.confession C.maine D.court tv E.trial
# A.school B.notebook C.meeting D.college E.desk
# A.eat ice cream B.buy beer C.bathe D.dive E.cool off
# A.belittlement B.slight C.dishonor D.being rude E.irreverence
# A.raise children B.an addition C.what people want D.offspring E.have children
# A.car crash B.gas pedal C.speeding ticket D.use gas E.doze off
# A.not washing hands B.lab C.hospital D.third world country E.human body
# A.separate B.leave C.quit D.opt out E.split apart
# A.hospitals B.maternity ward C.doctor's office D.school E.airport
# A.theatre B.butt C.stadium D.auditorium E.opera house
# A.box B.report on temperature C.cabinet D.drawer E.hospital
# A.drugstore B.woman's body C.human D.drugstore E.person's chest
# A.traffic B.solar system C.orbit D.universe E.cape canaveral
# A.class room B.college class C.library D.every aspect of life E.university
# A.kitchen B.freezer C.butcher shop D.frying pan E.fridge
# A.not working B.sitting down C.relaxation D.vacation E.renewal
# A.coal or wood B.solar energy C.energy D.fire E.house
# A.hide B.read text C.play dumb D.enjoy learning E.cross street
# A.sneeze B.sharing of ideas C.breathe D.speak E.story telling
# A.building B.theater C.board room D.office E.meeting
# A.eat cake B.steal C.selling D.save money E.paying
# A.forest B.home C.windows D.paint store E.house
# A.fall season B.roof C.tree D.ground E.forest
# A.mail B.hotel C.metropolitan city D.shopping center E.post office
# A.passion B.get laid C.accomplish goals D.talk about themselves E.own house
# A.high school B.nuclear power plant C.recording studio D.prison E.building
# A.refrigerator B.the field C.farmer's market D.store E.supermarket
# A.greater manchester B.lancashire C.cheshire D.england E.england
# A.neighborhood B.property C.michigan D.outside E.city
# A.drink B.fly C.reproduce asexually D.gay E.bite
# A.get free B.blood C.bruises D.falling down E.competition
# A.extraordinary B.beautiful C.irregular D.unusual E.special
# A.relax B.clear conscience C.go to sleep D.die E.get into bed
# A.jump several feet B.hop C.leap D.hop several feet E.swim
# A.ocean B.true C.prime D.just E.excellent
# A.for fun B.have to wait for C.anxiety D.terrible E.wait turn
# A.work B.dream C.tamper D.fiddle E.play games
# A.live forever B.male or female C.accomadable D.very adaptable E.emotional
# A.nature B.field C.vegetable garden D.neighbor's yard E.botanic garden
# A.anxiety B.success C.headaches D.graduating E.failure
# A.ruin B.michigan C.use D.let spoil E.rot
# A.pleasure B.having fun C.losing D.injury E.lose
# A.sea B.auditorium C.lake D.stadium E.ocean
# A.lakehouse B.hell C.baseball stadium D.africa E.baseball diamond
# A.looking stars through window B.entertainment C.wasted time D.relaxation E.falling asleep
# A.sweat B.weight loss C.get in shape D.scream E.relaxation
# A.early death B.happiness C.acquiring knowledge D.book burnings E.existing
# A.do nothing B.hurting C.observant D.hinder E.leave
# A.distillery B.fraternity house C.plane D.hot air balloon E.wine
# A.accompaniment to meal B.home C.menu D.the kitchen E.cafeteria
# A.countryside B.tree C.forest D.roof E.sky
# A.need money B.drink tea C.have to sleep D.say hello E.eat sushi
# A.satisfaction B.better health C.eat right D.losing weight E.breathlessness
# A.sit down B.run like 'run lola run' C.get physical activity D.sleep E.have rest
# A.butterflies B.energetic C.anxiety D.happiness E.pride
# A.debt B.cardiac arrest C.stress D.happiness E.pleasure
# A.locker B.bus terminal C.automobile D.garage E.file cabinet
# A.city B.children C.populated area D.every town E.christian community
# A.home B.barn C.alley D.outside E.lap
# A.books B.mouth C.newspaper D.sentence E.page of book
# A.clinic B.vein C.battlefield D.street E.needle
# A.close fitting B.bind C.engage D.fast E.tighten
# A.place B.computer store C.human body D.nature E.computer science
# A.purr B.claw C.think D.eat meat E.drink water
# A.meaning of life B.thinking C.revelations D.discovery E.reflection
# A.research B.watch film C.have conversation D.go to performance E.see particular program
# A.table B.piggy bank C.purse D.pocket E.cash drawer
# A.art room B.school C.desk drawer D.classroom E.library
# A.freeway B.street C.donut shop D.sidewalk E.police station
# A.amusement park B.city C.people D.vehicles E.apartment complex
# A.trophy or ribbon B.evaluating C.responsibility D.verdict E.prejudice
# A.casino B.losing money C.lose money D.penury E.bankruptcy
# A.ask many questions B.clean room C.wave goodbye D.play video games E.give a hug
# A.relief B.think C.calm down D.relax E.go swimming
# A.hat shop B.man's hat C.mall D.craft store E.clothes
# A.michigan B.ghana C.town D.wimbledon E.park
# A.harsh B.abrasive C.hard D.sensible E.loud
# A.work shop B.tool store C.tool shed D.dentist office E.repair shop
# A.promote internally B.own resources C.commit crime D.own factory E.branch out
# A.cooking pot B.pot C.fish market D.tide pool E.beach sand
# A.zoo B.drink water C.jungle D.india E.canada
# A.excitement B.stress C.envy D.longing E.looking at wrist watch
# A.concentrate B.read books C.assignment D.have book E.concentration
# A.bridge B.new mexico C.place D.belfry E.dug out
# A.december B.cloud C.air D.snow storm E.winter
# A.making friends B.have fun C.having fun D.anxiety E.billys mom
# A.water garden B.eat fruit C.catch cold D.jump for joy E.feel stupid
# A.freeway B.front door C.donut shop D.tire shop E.street
# A.motel B.theater C.having someplace to stay D.comfort E.camp ground
# A.save money B.cry C.own house D.better job E.feel safe
# A.board game B.lose C.competition D.throwing E.having fun
# A.snore B.awake C.sleep D.chair E.floor
# A.bathroom B.fast food restaurant C.house D.conference E.library
# A.hot room B.waiting room C.car D.house E.offices
# A.play B.unemployment C.laziness D.unemployed E.fly
# A.petri dish B.finger C.ground D.septic tank E.water
# A.falling down B.prohibit C.fall down D.get away with E.maintain balance
# A.look up B.go to church C.speak to god D.kneel E.dip fingers in holy water
# A.getting tired B.boredom C.sharing information D.spitting nails E.confusion
# A.glass B.street C.puddle D.soup E.ocean
# A.go to jail B.die C.dead D.kill E.done
# A.wilderness B.tropical jungle C.woods D.basement E.amazonia
# A.eating food B.weight gain C.getting fat D.being over weight E.being full
# A.pond B.country club C.monopoly game D.wall street E.michigan
# A.alien B.guide foreigners C.foreigner D.immigrant E.introduced
# A.neighborhood B.city C.city D.subdivision E.countryside
# A.running B.feeling better C.doing nothing D.recuperation E.relaxation
# A.mouth B.kentucky fried chicken C.human D.mouth E.jars and all faces
# A.eat dinner B.say hi C.greet D.shake hands E.have coffee
# A.wet B.interests C.interesting D.complex E.learn more about
# A.energy B.pollution C.go somewhere D.have money E.decide where to
# A.rain cloud B.bath tub C.ocean D.wishing well E.lake or river
# A.broken heart B.hospitalized C.annoyance D.ridiculous E.railway station
# A.high school B.spa C.pool D.college campus E.being healthy
# A.central park B.state fair C.american southwest D.nyc E.canada
# A.anxiety B.have to wait for C.longer lines D.fatigue E.late
# A.post office B.assay office C.butcher shop D.music store E.university
# A.great relief B.slashes C.beauty D.new look E.new color
# A.cemetary B.city C.archeological site D.canada E.construction site
# A.spread B.result in death C.kill D.bad E.illness occur
# A.pennslyvania B.indiana C.suburbs D.forest E.downtown
# A.drawer B.bathroom C.hair salon D.use E.turn it off
# A.corner B.rug C.library D.kitchen E.table
# A.park B.grocery store C.prison D.homeless shelter E.bar
# A.park B.washington state C.fields D.new york E.rain forest
# A.lactose B.water C.water D.calcium E.refrigerator
# A.learn B.friendship C.persuaded D.listen E.communication
# A.anxiety B.fatigue C.wait turn D.satisfied E.terrible
# A.golf course B.swiss cheese C.play ground D.notebook paper E.doughnut
# A.drawer B.suitcase C.closet D.floor E.house
# A.stress B.arriving at desination C.impulse buying D.an empty wallet E.carrying bags
# A.satisfy hunger B.cook one C.hungry D.good to eat E.protein
# A.jungle B.video game C.airport D.maze E.hotel
# A.minnesota B.thermal C.feathers D.photograph E.colorado
# A.work B.fashioned into simple tools C.drawer D.desktop E.university
# A.london B.urban areas C.restuarant D.gas stations E.city
# A.drink water B.buck C.eat oats D.canter E.trot
# A.central park B.museum C.church D.water fountain E.new york city
# A.roof B.air C.park D.swimming E.countryside
# A.electrical circuit B.putting together C.breakdance D.working E.accelerate
# A.world B.dark place C.forest D.woods E.zoo
# A.roast B.keep alive C.lie down D.need to eat E.bite
# A.state park B.trigonometry C.fairgrounds D.zoos E.laboratory
# A.falling asleep B.applaud C.hear about neat D.taking notes E.learning
# A.falsely B.negative C.nonpositive D.bad E.uncertain
# A.store objects B.can catch ball C.store clothes D.hold things E.store food
# A.answer B.initiate C.ignore D.response E.question
# A.drum store B.own home C.sun dress D.orchestra E.music store
# A.monetary B.money C.feeling bad D.sympathetic E.care
# A.reused B.burnt C.written on D.printed upon E.recycled
# A.social disruption B.accept society C.social activism D.change yourself E.argue
# A.drawer B.ignition switch C.controlling whether door opened D.firearm E.door
# A.classroom B.hotel C.populated areas D.supermarket E.race track
# A.knife B.helicopter C.scissors D.tape dispenser E.lawn mower
# A.front yard B.michigan C.forest D.outside of house E.urban area
# A.ally B.proponent C.advocate D.supporter E.companion
# A.school B.class C.shop D.space shuttle E.trunk
# A.learn about B.learned C.complex D.buy E.interesting
# A.solar energy B.bedroom C.body heat D.car E.coal or wood
# A.sleep B.talk nonsense C.boy or girl D.arrive early E.learn to walk
# A.stand alone B.cross street C.fall asleep D.try again E.give up
# A.house B.bedroom C.mansion D.dressing room E.clothes cupboard
# A.pillage norway B.dress nice C.bathe D.go for haircut E.wait for
# A.force B.car C.accelerate D.fuel system E.airplane
# A.blustery B.stressed C.wild D.disturbed E.windy
# A.at a store B.box C.shelf D.cabinet E.cupboard
# A.desk drawer B.lady's purse C.blotter D.behind ear E.shirt pocket
# A.avoid eye contact B.blush C.turn inside out D.feel guilty E.fall asleep
# A.fitness B.lose weight C.fatigue D.socks E.getting in shape
# A.prosperity B.earning money C.chiseling D.creation E.getting paid
# A.tuxedo B.party C.big house D.men's room E.church
# A.falling asleep B.solitude C.uniqueness D.relaxation E.discomfort
# A.house B.library C.at hotel D.salon E.telephone booth
# A.personal home B.golf course C.emergency room D.nursing home E.medical school
# A.pass out B.stop bicycle C.examine thing D.stay in bed E.reach tentative agreement
# A.coffee table B.hutch C.north carolina D.own home E.great britain
# A.dancing with kids B.babies C.getting drunk D.laughter E.happiness
# A.hospital B.building C.cave D.house E.airport
# A.teaching B.embarassment C.job interview D.people will understand E.children will learn
# A.expensive B.disrespect C.valuable D.worthlessness E.invaluable
# A.write B.have fever C.die D.have to sleep E.smile
# A.cubicle B.porch C.living room D.church E.kitchen
# A.nostalgia B.sneeze C.being prepared D.writing down E.phoning
# A.sail boat B.swim C.laugh at himself D.cross street E.hurry up
# A.ground B.idaho C.countryside D.oil field E.kansas
# A.standing in line B.debt C.spending money D.tiredness E.being broke
# A.sexual attraction B.smile C.cry D.personality E.getting excited
# A.dying B.end life C.happy D.drive into oncoming truck E.pain
# A.talking B.get cold C.snoring D.might dream E.running
# A.cap B.pillow C.style look D.bird cage E.birds nest
# A.library B.desktop C.classroom D.desk drawer E.backpack
# A.stds B.unwanted pregnancy C.orgasm D.bliss E.getting pregnant
# A.gathering information B.impress teacher C.headaches D.inspiration E.knowing more
# A.fly B.floor C.back yard D.warm place E.beam of sunlight
# A.negotiate B.settle down C.bargain D.lose money E.pay for
# A.chills B.better decisions C.swim D.calm down E.expansion
# A.war B.security C.pants D.police station E.police officer's belt
# A.ask questions B.estimate value C.better comprehension D.study books E.read books
# A.superior B.insight C.determination D.skill E.upper hand
# A.refrigerator B.pizza C.table D.kitchen E.pantry
# A.commit crime B.die C.being caught D.feel mad E.feel anger
# A.floor B.houseplant C.urban neighborhood D.container E.dumpsters
# A.cabinet B.shelf C.fall off shelf D.windowsill E.table
# A.apply glue to surfaces B.office C.bedroom D.desk drawer E.classroom
# A.get caught B.mistrust C.being fired D.problems E.broken heart
# A.flooding B.blizzard C.drowning D.surface of earth E.cactus
# A.crying B.headaches C.decision D.enlightenment E.new thoughts
# A.garden B.cabinet C.factory D.bedroom E.juice
# A.town B.car C.pedestrian path D.business district E.city
# A.get wet B.wet hair C.wet skin D.drowning E.rash
# A.opera B.bathroom C.carnival D.night club E.elevator
# A.ample B.bareword C.covered D.full E.dressed
# A.sense of fulfillment B.clear thought C.thinking D.deep thoughts E.contemplating
# A.warehouse B.laboratory C.meat van D.refrigerator E.grocery store
# A.stand B.complete test C.do mathematics D.begin to study E.learn language
# A.satisfaction B.kindness C.pay D.heart E.happiness
# A.cafe B.advertisement C.bar D.computer program E.internet sites
# A.hasten B.work C.stop D.act E.decide
# A.opera B.hockey game C.hospital D.water cooler E.office
# A.elapsed time B.happiness C.movement D.relaxation E.uneasiness
# A.drawer B.cupboard C.dorm D.refrigerator E.sitting room
# A.michigan B.country C.counties D.rural areas E.map
# A.palace B.floor C.den D.house E.family room
# A.people B.stores C.suburbs D.populated area E.urban area
# A.supermarket B.circus C.birthday party D.toy store E.amusement park
# A.iowa B.kentucky C.miami D.town E.england
# A.kiss B.copulate C.go to party D.procreate E.have sex
# A.hospitalized B.broken heart C.schizophrenia D.cold E.annoyance
# A.tape B.buy tickets C.find out when D.hatred E.stop channelsurfing
# A.shelf B.demonstration C.store D.ground E.market
# A.own people B.go outside C.fed us D.reproduce E.need food
# A.town B.freeway C.major city D.high traffic area E.highway
# A.pantry B.bar C.motherboard D.supermarket E.work
# A.sadness B.arm himself C.receive mail D.feel sleepy E.catch cold
# A.box B.office building C.backpack D.school E.table
# A.watch television B.play basketball C.cut and paste D.swimming E.reach over
# A.shelf B.apartment C.cabinet D.dining room E.pantry
# A.punch B.calm C.field D.sweetness E.happiness
# A.pair of trousers B.on holiday C.classroom D.great britain E.bad mood
# A.welcome change B.catch cold C.become depressed D.pay bills E.say hi
# A.bad B.horrible C.poor performance D.awful E.poor

# %%
# inspect a sample from our preprocessed data
massaged_datasets["train"][0]
# Out:
# {'id': '075e483d21c29a511267ef62bedc0461',
#  'question': 'The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?',
#  'question_concept': 'punishing',
#  'choices': {'label': ['A', 'B', 'C', 'D', 'E'],
#   'text': ['ignore', 'enforce', 'authoritarian', 'yell at', 'avoid']},
#  'answerKey': 'A',
#  'text': 'The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change? A.ignore B.enforce C.authoritarian D.yell at E.avoid\nAnswer: A'}

# %%
def tokenize(tokenizer, example):
    """
    Helper for pre-tokenizing all examples.
    """
    tokenized = tokenizer(
        example["text"],
        # we are fixing the length to 64 tokens to avoid memory issues
        max_length=64,
        padding="max_length",
        truncation=True,
        return_tensors="pt",
    )
    return tokenized


print(massaged_datasets.column_names)
tokenized_dataset = massaged_datasets.map(
    lambda example: tokenize(tokenizer,example),
    batched=True,
    remove_columns= ["id", "question", "question_concept", "choices", "answerKey"]
)
# Out:
# {'train': ['id', 'question', 'question_concept', 'choices', 'answerKey', 'text'], 'validation': ['id', 'question', 'question_concept', 'choices', 'answerKey', 'text'], 'test': ['id', 'question', 'question_concept', 'choices', 'answerKey', 'text']}
# Map:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1221 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1140 [00:00<?, ? examples/s]

# %%
# move to accelerated device
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Device: {device}")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print(f"Device: {device}")
else:
    device = torch.device("cpu")
    print(f"Device: {device}")
# Out:
# Device: cpu

# %%
# 2. init model

# load pretrained Pythia-160M for HF
model = AutoModelForCausalLM.from_pretrained(
  "EleutherAI/pythia-160m",
  token= "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"
)

# print num of trainable parameters
model_size = sum(t.numel() for t in model.parameters())
print(f"Pythia-160m size: {model_size/1000**2:.1f}M parameters")
# Out:
# config.json:   0%|          | 0.00/569 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/375M [00:00<?, ?B/s]
# Pythia-160m size: 162.3M parameters

# %% [markdown]
# Hint: If you run out of memory while trying to run the training, try decreasing the batch size.

# %%
# 3. set up configurations required for the training loop

# instantiate tokenized train dataset
train_dataset = massaged_datasets["train"].map(
    lambda example: tokenizer(example["text"],
                              max_length=64, padding="max_length",truncation=True),
    batched=True,
    remove_columns=massaged_datasets["train"].column_names
)

# instantiate tokenized validation dataset
validation_dataset = massaged_datasets["validation"].map(
    lambda example: tokenizer(example["text"],
                              max_length=64, padding="max_length",truncation=True),
    batched=True,
    remove_columns=massaged_datasets["train"].column_names
)


# instantiate a data collator
collate_fn = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
# create a DataLoader for the dataset
# the data loader will automatically batch the data
# and iteratively return training examples (question answer pairs) in batches
dataloader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    collate_fn=collate_fn,
)
# create a DataLoader for the test dataset
# reason for separate data loader is that we want to
# be able to use a different index for retreiving the test batches
# we might also want to use a different batch size etc.
validation_dataloader = DataLoader(
    validation_dataset,
    batch_size=16,
    shuffle=True,
    collate_fn=collate_fn
)
# Out:
# Map:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1221 [00:00<?, ? examples/s]

# %%
# 4. run the training of the model
# Hint: for implementing the forward pass and loss computation, carefully look at the exercise sheets
# and the links to examples in HF tutorials.

# put the model in training mode
model.train()
# move the model to the device (e.g. GPU)
model = model.to(device)

# trianing configutations
# feel free to play around with these
epochs  = 10
train_steps =  5
print("Number of training steps: ", train_steps)
# number of validation steps to perform every 10 training steps
# (smaller than the entire validation split for reasons of comp. time)
num_test_steps = 5

# define optimizer and learning rate
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-4)
# define some variables to accumulate the losses
losses = []
validation_losses = []

# iterate over epochs
for e in range(epochs):
    # iterate over training steps
    for i in tqdm(range(train_steps)):
        # get a batch of data
        x = next(iter(dataloader))
        # move the data to the device (GPU)
        x =  {k: v.to(device) for k, v in x.items()}


        # forward pass through the model
        ### YOUR CODE HERE ###
        outputs = model(
            **x
        )
        # get the loss
        loss = outputs.loss
        # backward pass
        loss.backward()
        losses.append(loss.item())
        # update the parameters of the model
        optimizer.step()


        # zero out gradient for next step
        optimizer.zero_grad()

        # evaluate on a few steps of validation set every 10 steps
        if i % 10 == 0:
            print(f"Epoch {e}, step {i}, loss {loss.item()}")
            # track test loss for the evaluation iteration
            val_loss = 0
            for j in range(num_test_steps):
                # get test batch
                x_test = next(iter(validation_dataloader))
                x_test = x_test.to(device)
                with torch.no_grad():
                    test_outputs = model(**x_test)
                val_loss += test_outputs.loss.item()

            avg_val_loss = val_loss / num_test_steps
            validation_losses.append(val_loss / num_test_steps)
            print("Test loss: ", val_loss/num_test_steps)
# Out:
# Number of training steps:  5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 0, step 0, loss 4.61411190032959
#  20%|██        | 1/5 [00:45<03:01, 45.41s/it]
# Test loss:  9.665239906311035
# 100%|██████████| 5/5 [01:53<00:00, 22.64s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1, step 0, loss 15.560445785522461
#  20%|██        | 1/5 [00:43<02:52, 43.19s/it]
# Test loss:  16.22164421081543
# 100%|██████████| 5/5 [01:49<00:00, 21.83s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 2, step 0, loss 12.660917282104492
#  20%|██        | 1/5 [00:41<02:44, 41.23s/it]
# Test loss:  14.307570457458496
# 100%|██████████| 5/5 [01:48<00:00, 21.62s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 3, step 0, loss 12.492147445678711
#  20%|██        | 1/5 [00:41<02:44, 41.04s/it]
# Test loss:  12.076986694335938
# 100%|██████████| 5/5 [01:46<00:00, 21.37s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 4, step 0, loss 11.899714469909668
#  20%|██        | 1/5 [00:40<02:43, 40.85s/it]
# Test loss:  12.315561866760254
# 100%|██████████| 5/5 [01:57<00:00, 23.54s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 5, step 0, loss 12.711922645568848
#  20%|██        | 1/5 [00:43<02:55, 43.77s/it]
# Test loss:  14.01674289703369
# 100%|██████████| 5/5 [01:55<00:00, 23.08s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 6, step 0, loss 12.0255126953125
#  20%|██        | 1/5 [00:45<03:03, 45.92s/it]
# Test loss:  11.288862991333009
# 100%|██████████| 5/5 [01:59<00:00, 23.85s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 7, step 0, loss 10.428871154785156
#  20%|██        | 1/5 [00:42<02:51, 42.87s/it]
# Test loss:  10.7965482711792
# 100%|██████████| 5/5 [01:50<00:00, 22.14s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 8, step 0, loss 10.591347694396973
#  20%|██        | 1/5 [00:41<02:44, 41.18s/it]
# Test loss:  11.225733757019043
# 100%|██████████| 5/5 [01:56<00:00, 23.27s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 9, step 0, loss 11.522261619567871
#  20%|██        | 1/5 [00:44<02:59, 44.76s/it]
# Test loss:  10.800217056274414
# 100%|██████████| 5/5 [01:59<00:00, 23.80s/it]

# %%
# 5. Plot the fine-tuning loss and MAKE SURE TO SAVE IT AND SUBMIT IT

# plot training losses on x axis
plt.plot(losses, label="train loss")
plt.plot(validation_losses, label="validation loss")
plt.xlabel("Training steps")
plt.ylabel("Losses")
# Out:
# Text(0, 0.5, 'Losses')

# %%
# print a few predictions on the eval dataset to see what the model predicts

# construct a list of questions without the ground truth label
# and compare prediction of the model with the ground truth

def construct_test_samples(example):
    """
    Helper for converting input examples which have
    a separate qquestion, labels, answer options
    into a single string for testing the model.

    Arguments
    ---------
    example: dict
        Sample input from the dataset which contains the
        question, answer labels (e.g. A, B, C, D),
        the answer options for the question, and which
        of the answers is correct.

    Returns
    -------
    input_text: str, str
        Tuple: Formatted test text which contains the question,
        the forwatted answer options (e.g., 'A. <option 1> B. <option 2>' etc);
        the ground truth answer label only.
    """

    answer_options_list = list(zip(
        example["choices"]["label"],
        example["choices"]["text"]
    ))
    # join each label and text with . and space
    answer_options = [f"{label}. {text}" for label, text in answer_options_list]
    # join the list of options with spaces into single string
    answer_options_string = " ".join(answer_options)
    # combine question and answer options
    input_text = example["question"] + " " + answer_options_string
    # create the test input text which should be:
    # the input text, followed by the string "Answer: "
    # we don't need to append the ground truth answer since we are creating test inputs
    # and the answer should be predicted.
    input_text += " Answer:"

    return input_text, example["answerKey"]

test_samples = [construct_test_samples(dataset["validation"][i]) for i in range(10)]
test_samples
# Out:
# [('A revolving door is convenient for two direction travel, but it also serves as a security measure at a what? A. bank B. library C. department store D. mall E. new york Answer:',
#   'A'),
#  ('What do people aim to do at work? A. complete job B. learn from each other C. kill animals D. wear hats E. talk to each other Answer:',
#   'A'),
#  ('Where would you find magazines along side many other printed works? A. doctor B. bookstore C. market D. train station E. mortuary Answer:',
#   'B'),
#  ('Where are  you likely to find a hamburger? A. fast food restaurant B. pizza C. ground up dead cows D. mouth E. cow carcus Answer:',
#   'A'),
#  ('James was looking for a good place to buy farmland.  Where might he look? A. midwest B. countryside C. estate D. farming areas E. illinois Answer:',
#   'A'),
#  ('What island country is ferret popular? A. own home B. north carolina C. great britain D. hutch E. outdoors Answer:',
#   'C'),
#  ("In what Spanish speaking North American country can you get a great cup of coffee? A. mildred's coffee shop B. mexico C. diner D. kitchen E. canteen Answer:",
#   'B'),
#  ('What do animals do when an enemy is approaching? A. feel pleasure B. procreate C. pass water D. listen to each other E. sing Answer:',
#   'D'),
#  ('Reading newspaper one of many ways to practice your what? A. literacy B. knowing how to read C. money D. buying E. money bank Answer:',
#   'A'),
#  ('What do people typically do while playing guitar? A. cry B. hear sounds C. singing D. arthritis E. making music Answer:',
#   'C')]

# %%
# Test the model

# set it to evaluation mode
model.eval()

predictions = []
for sample in test_samples:
    input_text = sample[0]
    input_ids = tokenizer(input_text, return_tensors="pt").to(device)
    output = model.generate(
        input_ids.input_ids,
        attention_mask = input_ids.attention_mask,
        max_new_tokens=2,
        do_sample=True,
        temperature=0.4,
    )
    prediction = tokenizer.decode(output[0], skip_special_tokens=True)
    predictions.append((input_text, prediction, sample[1]))

print("Predictions of trained model ", predictions)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Predictions of trained model  [('A revolving door is convenient for two direction travel, but it also serves as a security measure at a what? A. bank B. library C. department store D. mall E. new york Answer:', 'A revolving door is convenient for two direction travel, but it also serves as a security measure at a what? A. bank B. library C. department store D. mall E. new york Answer: to:', 'A'), ('What do people aim to do at work? A. complete job B. learn from each other C. kill animals D. wear hats E. talk to each other Answer:', 'What do people aim to do at work? A. complete job B. learn from each other C. kill animals D. wear hats E. talk to each other Answer:..', 'A'), ('Where would you find magazines along side many other printed works? A. doctor B. bookstore C. market D. train station E. mortuary Answer:', 'Where would you find magazines along side many other printed works? A. doctor B. bookstore C. market D. train station E. mortuary Answer:..', 'B'), ('Where are  you likely to find a hamburger? A. fast food restaurant B. pizza C. ground up dead cows D. mouth E. cow carcus Answer:', 'Where are  you likely to find a hamburger? A. fast food restaurant B. pizza C. ground up dead cows D. mouth E. cow carcus Answer:..', 'A'), ('James was looking for a good place to buy farmland.  Where might he look? A. midwest B. countryside C. estate D. farming areas E. illinois Answer:', 'James was looking for a good place to buy farmland.  Where might he look? A. midwest B. countryside C. estate D. farming areas E. illinois Answer:..', 'A'), ('What island country is ferret popular? A. own home B. north carolina C. great britain D. hutch E. outdoors Answer:', 'What island country is ferret popular? A. own home B. north carolina C. great britain D. hutch E. outdoors Answer:..', 'C'), ("In what Spanish speaking North American country can you get a great cup of coffee? A. mildred's coffee shop B. mexico C. diner D. kitchen E. canteen Answer:", "In what Spanish speaking North American country can you get a great cup of coffee? A. mildred's coffee shop B. mexico C. diner D. kitchen E. canteen Answer:..", 'B'), ('What do animals do when an enemy is approaching? A. feel pleasure B. procreate C. pass water D. listen to each other E. sing Answer:', 'What do animals do when an enemy is approaching? A. feel pleasure B. procreate C. pass water D. listen to each other E. sing Answer:.:', 'D'), ('Reading newspaper one of many ways to practice your what? A. literacy B. knowing how to read C. money D. buying E. money bank Answer:', 'Reading newspaper one of many ways to practice your what? A. literacy B. knowing how to read C. money D. buying E. money bank Answer:..', 'A'), ('What do people typically do while playing guitar? A. cry B. hear sounds C. singing D. arthritis E. making music Answer:', 'What do people typically do while playing guitar? A. cry B. hear sounds C. singing D. arthritis E. making music Answer:braskabus', 'C')]

# %% [markdown]
# Questions:
# > 1. Provide a brief description of the CommonsenseQA dataset. What kind of task was it developed for, what do the single columns contain?
# It is a dataset for common sense question answering task. The columns contain question, question types, answers with 5 choices with their label A ,B, C, D ,E.
# > 2. What loss function is computed for this training? Provide the name of the function (conceptual, not necessarily the name of a function in the code).
# We did not explicitly pass a loss function to the training, the Trainer constructs it automatically. The name is Cross Entropy Loss since the HuggingFace Trainer uses it internally when a custom loss function is not defined.
# > 3. Given your loss curve, do you think your model will perform well on answering common sense questions? (Note: there is no single right answer; you need to interpret your specific plot)
# My plot looks quite unstable and noisy. Initially, it has a very sharp increase followed by sharp fluctuations and a non-smooth downward trend. Model doesn't seem to learn very effectively, it doesn't show smoothnes, convergence and has a high loss in the beginning. This could be underfitting or epoch or training step size could be increased.
# > 4. Inspect the predictions above. On how many test questions did the model predict the right answer? Compute the accuracy.
# Model predicted 10/10 and it has 100% accuracy.
