# %% [markdown]
# Homework 4: LLM evaluation (59 points)
# =====
#
# The third homework zooms in on evaluating LLMs, specifically, on the following skills: using log probabilities of string under a trained LM to evaluate it, coming up with items to test particular aspets of LLMs, and comparing LLM measures to measures of human performance.
#
# ### Logistics
#
# * submission deadline: July 15th th 23:59 German time via Moodle
#   * please upload a **SINGLE .IPYNB FILE named Surname_FirstName_HW4.ipynb** containing your solutions of the homework. Make sure that your **plots** for the last exercise are either rendered in the notebook or submitted together with it in a zip file.
# * please solve and submit the homework **individually**!
# * if you use Colab, to speed up the execution of the code on Colab, you can use the available GPU (if Colab resources allow). For that, before executing your code, navigate to Runtime > Change runtime type > GPU > Save.
#
# **NOTE:** It might be that, on Colab, you run out of memory between the exercises. You might need to restart the runtime / it will restart automatically. After the restart, you might need to re-install packages. Furthermore, if you work on Colab, do not leave working on these tasks to the last minute, as Colab sometimes limits access to GPU runtime / day if one tries to restart access GPUs frequently.

# %% [markdown]
# ## Exercise 1: Understanding grammatical capabilities of LLMs (10 points)
#
# In this task, we look at [BLiMP](https://aclanthology.org/2020.tacl-1.25/), the benchmark of linguistic minimal pairs. This is a well-known benchmark for evaluating linguistic capabilities of language models. It consists of 67 individual datasets, each containing 1,000 minimal pairs -- that is, pairs of minimally different sentences that contrast in grammatical acceptability and isolate specific phenomenon in syntax, morphology, or semantics. The authors suggest to use the benchmark to evaluate LMs by observing whether they assign a higher probability to the acceptable sentence in each minimal pair.
#
# > Your task is to evaluate an open-source model, [Olmo-2-1B-Instruct](https://huggingface.co/allenai/OLMo-2-0425-1B-Instruct), on this benchmark by completing the code below. Based on your evaluation results, please answer the following questions.
# > Please use the following test suites to answer them: anaphor_gender_agreement, determiner_noun_agreement_with_adjective_1, animate_subject_passive, complex_NP_island, npi_present_1, superlative_quantifiers_1, existential_there_object_raising, principle_A_case_1.
# >
# > The entire benchmark can be found [here](https://huggingface.co/datasets/nyu-mll/blimp).
# >
# > 1. Plot the accuracy of the model on the different grammatical phenomena, represented in different test suites.
# > 2. Calculate the average accuracies and the confidence intervals in the different fields: syntax, morphology, syntax-semantics, semantics. Is the performance the same across the different fields? Which field is the most difficult one?
# > * Easiest field is morphology with 0.9535 accuracy.
# > * The most difficult field is syntax with  0.6795 accuracy.
# > 3. What is the easiest grammatical phenomenon, what is the most difficult grammatical phenomenon (as captured by the single test suites) for the model?
#
# > * The easiest test suit is principle_A_case_1     with                        1.000 accuracy.
# > * The most difficult test suite is complex_NP_island                    with          0.653 accuracy.

# %% [markdown]
# Note: you might be prompted to reload your runtime after installing minicons, and you might see some deprecation warnings / dependency incompatibilities when it is installed. Please ignore these warnings (usually not the best practice, we know!).

# %%
# %%capture
# !pip install minicons
# !pip install -U datasets huggingface_hub fsspec

# %%
from datasets import load_dataset, concatenate_datasets , DatasetDict
import torch
from minicons import scorer
import numpy as np
import pandas as pd

# %%
import torch
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

# %%
# iterate over the test suites
test_suites = { "anaphor_gender_agreement",
               "determiner_noun_agreement_with_adjective_1",
               "animate_subject_passive",
               "complex_NP_island",
               "npi_present_1",
               "superlative_quantifiers_1",
               "existential_there_object_raising",
               "principle_A_case_1"
               }

dataset_suits=[]
for test_suite in test_suites:
  dataset = load_dataset("nyu-mll/blimp", test_suite)["train"]
  dataset_suits.append(dataset)

merged_dataset = DatasetDict({
    "train": concatenate_datasets(dataset_suits)
})
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Check if the dataset is correctly concatenated
print(len(merged_dataset["train"]))

print(set(merged_dataset["train"]["UID"]))

from collections import Counter
print(Counter(merged_dataset["train"]["UID"]))

from collections import Counter
print(Counter(merged_dataset["train"]["field"]))
# Out:
# 8000
# {'determiner_noun_agreement_with_adjective_1', 'superlative_quantifiers_1', 'existential_there_object_raising', 'npi_present_1', 'complex_NP_island', 'anaphor_gender_agreement', 'principle_A_case_1', 'animate_subject_passive'}
# Counter({'determiner_noun_agreement_with_adjective_1': 1000, 'superlative_quantifiers_1': 1000, 'existential_there_object_raising': 1000, 'npi_present_1': 1000, 'complex_NP_island': 1000, 'anaphor_gender_agreement': 1000, 'principle_A_case_1': 1000, 'animate_subject_passive': 1000})
# Counter({'morphology': 2000, 'semantics': 2000, 'syntax_semantics': 2000, 'syntax': 2000})

# %%
# iterate over the single items of the test suite
# hint: you can use code similar to the one in sheet 7.1

# set up the model as a minicons scorer
lm_scorer = scorer.IncrementalLMScorer("allenai/OLMo-2-0425-1B-Instruct", device=device
)

# create some lists to store the results
results= []

# %%
for item in merged_dataset["train"]:
    # get the sentence pair
    sentence_good = item["sentence_good"]
    sentence_bad = item["sentence_bad"]

    score_good ,score_bad = lm_scorer.sequence_score([sentence_good, sentence_bad])
    #print(scores)

    results.append([
        score_good,
        score_bad,
        item["UID"],
        item["field"]
    ])

# %%
df_results = pd.DataFrame(results, columns=["score_good", "score_bad", "UID", "field"])
print(df_results["UID"].value_counts())
print(df_results["field"].value_counts())
# Out:
# UID
# determiner_noun_agreement_with_adjective_1    1000
# superlative_quantifiers_1                     1000
# existential_there_object_raising              1000
# npi_present_1                                 1000
# complex_NP_island                             1000
# anaphor_gender_agreement                      1000
# principle_A_case_1                            1000
# animate_subject_passive                       1000
# Name: count, dtype: int64
# field
# morphology          2000
# semantics           2000
# syntax_semantics    2000
# syntax              2000
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats


# calculate the performance by test suite
df_results["correct"] = df_results["score_good"] > df_results["score_bad"]

accuracy_per_UID = df_results.groupby("UID")["correct"].agg(["mean", "count"]).rename(columns={"mean": "accuracy"})
print(accuracy_per_UID)


# plot the results in a bar plot
plt.figure(figsize=(12,6))
plt.bar(accuracy_per_UID.index, accuracy_per_UID["accuracy"])
plt.xticks(rotation=45, ha='right')
plt.ylabel("Accuracy")
plt.title("Model Accuracy by Test Suite")
plt.ylim(0,1)
plt.tight_layout()
plt.show()
# Out:
#                                             accuracy  count
# UID
# anaphor_gender_agreement                       0.988   1000
# animate_subject_passive                        0.706   1000
# complex_NP_island                              0.653   1000
# determiner_noun_agreement_with_adjective_1     0.919   1000
# existential_there_object_raising               0.764   1000
# npi_present_1                                  0.749   1000
# principle_A_case_1                             1.000   1000
# superlative_quantifiers_1                      0.817   1000

# %%
# calculate the performance as described above by category and plot the results in a bar plot with CIs
fields = []
accuracies = []
cis = []

for field, group in df_results.groupby("field"):
    data = group["correct"].values
    n = len(data)
    mean = np.mean(data)
    sem = stats.sem(data)
    ci = sem * stats.t.ppf((1 + 0.95) / 2., n-1)

    fields.append(field)
    accuracies.append(mean)
    cis.append(ci)

accuracy_CI_per_field = pd.DataFrame({
    "accuracy": accuracies,
    "ci": cis
}, index=fields)

print(accuracy_CI_per_field)

accuracy_CI_per_field = accuracy_CI_per_field.sort_values("accuracy", ascending=False)

plt.figure(figsize=(8,5))
plt.bar(accuracy_CI_per_field.index, accuracy_CI_per_field["accuracy"], yerr=accuracy_CI_per_field["ci"], capsize=5, color='skyblue')
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.title("Model Accuracy by Field with 95% Confidence Intervals")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
#                   accuracy        ci
# morphology          0.9535  0.009236
# semantics           0.7830  0.018081
# syntax              0.6795  0.020470
# syntax_semantics    0.8820  0.014151

# %% [markdown]
# ## Exercise 2: Evaluating societal biases (13 points)

# %% [markdown]
# In this exercise, we will consider aspects of LLM performance which may have social implications and that are deeply interconnected with how humans use language. This task evaluates whether LLMs overrepresent certain cultures over others, which could be due to, e.g., imbalances over training data sources and languages.
#
# > Specifically, your task is to come up with an appropriate test item and evaluate whether LLMs exhibit certain cultural biases.
# > In this task, you have to construct your own multiple-choice test item for investigating cultural biases of LLMs, where, given a context, the different available response / continuation options would reflect preferences for responses typical for different cultures.
# > For instance, one response could be more acceptable under one particular cultural lens and another response under a different cultural background.
# > Your task is then to evaluate the performance of two LLMs: the mostly monolingual `gpt2-large` and the multilingual `bigscience/bloom-560m` model. The second part of the task is to complete the evaluation code and interpret the results by answering the question below.
# > Note that there obviously is no signle right answer to this, so we will assess the plausibility of your idea and the correctness of the code & interpretation.
#
# Here is a simple example of a test item. More explanations are in parentheses. You should provide analogous explanations in the answers to the questions below, but do not pass these to the LLMs during evaluations.
#
#
# Context 1: You are at a German supermarket. You walk up to the cashier and greet them by saying:
#
# Context 2: You are at an American supermarket. You walk up to the cashier and greet them by saying:
#
# A. Hello. (intuititvely, more likely in to be appropiate in the Germany context condition)
#
# B. Bye. (a generally inappropriate response)
#
# C. Hello, how are you? (intuitively, more likely to be appropriate in the US context condition; people usually don’t ask strangers ‘how are you’ in Germany)
#
# I would say: (insert each of the answer options separately here and calculate their log probability, given each of the contexts).

# %% [markdown]
# For reference about constructing datasets and inspiration, feel free to take a look at the [ETHICS dataset](https://arxiv.org/pdf/2008.02275), e.g., Fig. 2, where the authors came up with different continuations tapping into different conditions, given a context.
#
# > **Fill in your responses below.**
# >
# > 1. Your prompt (context 1 and 2, response options A-C; with explanations of the intuitive differences for each response option in respective cultural contexts):
# >
#
# > Context 1: You are a Muslim at a burger place in Germany. When you order,  you ask to the waiter:
# >
# > Context 2: You are a Hindu at a burger place in Germany. When you order , you ask to the waiter:
# >
# > A. What are the options without pig meat on the menu? (This question is more
# > likely to be asked by Muslims.)
# >
# > B. Can I get one cheeseburger menu please? (This can be asked by all of them , but usually after clarifying the meat type for the Muslim and Hindu person.)
# >
# > C. What are the options without beef on the menu? (This question is more likely to be asked by Hindus.)
# >
# > I would say:
# >
# ---
#
# > 2. Your model log probabilities (please fill in the table below with the conditional log probabilities you retrieved with the code below for your respective item):
# >
# > | Context / Option | GPT-2 | Bloom |
# > |------------------|-------|-------|
# > | context 1 + A      | -4.1684   |  -3.7568 |
# > | context 2 + A      |  -4.1238     | -3.8028      |
# > | context 1 + B      | -3.0745      | -2.5648      |
# > | context 2 + B      | -3.1502      |  -2.6176     |
# > | context 1 + C      | -4.0815	      | -3.4144      |
# > | context 2 + C      |  -3.8674     | -3.3475      |
#
#
# > 3. Do the models show a preference for a particular cultural setting (context 1 or context 2)? Is there evidence for whether cultural biases might be caused by training data?
# >
# >For my context and options, they always chose the general option. But from the possibilites , it is seen that models are more prone to choose context 2
# >(Hindu) for pig option, while it is also more possible for no beef option. So
# >it slightly favors context 1 for options, but in the end for both cultural
# >settings models choose general option. So, in the pretraining part, models
# >lack enough data for hinduism or islam , and maybe has more samples about
# >hinduism than islam.
#
# > 4. Are there aspects of the prompt that might influence your results? Please provide a brief justification / example why (not). Write 2 sentences max.
# >
# > I thought if I put an inappropriate answer rather than a general/ neutral one, models would choose the culturally biased ones because they are
# > more acceptable in these context and they chose the general option because
# > it is more common. However, I tested it also with an inappropriate response
# > such as 'Thank you.' and the results were like below :
# >
# > ```
# >   context 1 + A	-4.1684		-3.7568
# >   context 1 + B	-4.5645		-2.1291
# >   context 1 + C	-4.0815		-3.4144
# >   GPT-2 prediction for context 1: hindu
# >   BLOOM prediction for context 1: general
# >
# >   context 2 + A	-4.1238		-3.8028
# >   context 2 + B	-4.4799		-2.3211
# >   context 2 + C	-3.8674		-3.3475
# >   GPT-2 prediction for context 2: hindu
# >   BLOOM prediction for context 2: general
# >
# > ```
# > I also thought specifying Germany in the prompt could be a good choice as it is a multicultural country with many people from all around the world, but I think any country name or no country name would result the same because the data is trained on culture of western countries and the general answer is "too" general. This suggests model's behavior shaped by training data more.

# %%
from minicons import scorer
import pandas as pd

# %%
import torch
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device('cpu')

# %%
# here is some starter code; please fill in your code / comments where it says #### YOUR CODE / COMMENT HERE ####

# set up a scorer
gpt2_scorer = scorer.IncrementalLMScorer(
    'gpt2-large',device=device
)

bloom_scorer = scorer.IncrementalLMScorer(
    'bigscience/bloom-560m',device=device
)
# initialize list for storing the predictions
gpt2_predictions = []
bloom_predictions = []
answer_keys = ["muslim", "general", "hindu"]

contexts = [
    "You are a Muslim at a burger place in Germany. When you order, you ask the waiter:",
    "You are a Hindu at a burger place in Germany. When you order, you ask the waiter:",
]

# iterate over contexts
for context in range(len(contexts)):
    # format / provide  the possible answer options from your vignette
    answer_options = [
        "What are the options without pig meat on the menu?",
        "Can I get a cheeseburger menu, please?",
        "What are the options without beef on the menu?"
        ]

    prompt= [contexts[context] + " I would say: "] * len(answer_options)

    # pass a list of contexts and a list of continuations to be scored
    answer_scores_gpt2 = gpt2_scorer.conditional_score(
        # format the question into a list of same length as the number of answer options
        prompt,
        answer_options
    )
    answer_scores_bloom = bloom_scorer.conditional_score(
        # format the question into a list of same length as the number of answer options
        prompt,
        answer_options
    )

    # check / inspect which answer has the highest score and which answer type (i.e., "culture") it corresponds to
    gpt2_predictions.append(answer_scores_gpt2)
    bloom_predictions.append(answer_scores_bloom)

    best_answer_gpt2 = answer_keys[answer_scores_gpt2.index(max(answer_scores_gpt2))]
    best_answer_bloom = answer_keys[answer_scores_bloom.index(max(answer_scores_bloom))]

    for j in range(len(answer_options)):
        label = f"context {context+1} + {chr(65 + j)}"
        print(f"{label}\t{gpt2_predictions[context][j]:.4f}\t\t{bloom_predictions[context][j]:.4f}")

    print(f"GPT-2 prediction for context {context+1}: {best_answer_gpt2}")
    print(f"BLOOM prediction for context {context+1}: {best_answer_bloom}\n")
# Out:
# context 1 + A	-4.1684		-3.7568
# context 1 + B	-3.0745		-2.5648
# context 1 + C	-4.0815		-3.4144
# GPT-2 prediction for context 1: general
# BLOOM prediction for context 1: general
#
# context 2 + A	-4.1238		-3.8028
# context 2 + B	-3.1502		-2.6176
# context 2 + C	-3.8674		-3.3475
# GPT-2 prediction for context 2: general
# BLOOM prediction for context 2: general

# %% [markdown]
# ## Exercise 3: Theory of mind evaluations of LLMs (14 points)
#
# One capability that has been much debated in the context oflanguage models is so-called *theory-of-mind* (ToM) reasoning, a capability to reason about other people's latent mental states like beliefs and knowledge and how they influence the person's behavior.
#
# One well-known task to investigate theory of mind capabilities is the so-called False Belief task.
# We will use a benchmark [BigToM](https://arxiv.org/abs/2306.15448) that contains items with variations of this task generated trough LMs, specifically a subset of the forward and backward belief conditions.
# Please download the relevant data [here](https://github.com/CogSciPrag/Understanding-LLMs-course/tree/main/understanding-llms/homework/data/bigtom.csv).
#
# > Your task here is to:
# >
# > 1. Take a look at the paper to familiarize yourself with the benchmark. In max. two sentences per condition, explain what the forward and backward belief conditions of the benchmark test.
# >
# > * **Forward Belief condition tests** whether the model can predict agent's updated belief(true belief) after they witness the action that changes the state.
# > * **Backward Belief condition tests** whether the model can predict agent's prior belief(false belief) because they did not witness the action that changes the state.
# > 2. Complete the following code to evaluate the Olmo model from exercise 1 on the ToM benchmark (fill in the slots with ###YOUR CODE / COMMENT HERE ###). Specifically:
# >
# >   a. Evaluate the performance of the model when scoring the linguistic continuations of the sentence and comparing the respective conditional log probabilities. Compare the performance of the model in the false belief and the true belief conditions.
# > Model shows true belief accuracy around 0.54 and false belief accuracy around  0.74. This indicates model performs better under false belief conditions.
# >   b. Evaluate the performance of the model when formatting the prompt in a multiple choice format, where the two continuations for each prompt are included in the prompt along with labels (e.g., A., B.). Then, let the model generate a few tokens and check if the correct answer label was predicted. . Compare the performance of the model in the false belief and the true belief conditions.
# > I got 0 or close to 0 accuracies for this task, because model was generating an additional option labelled "C" and always choosing it. I think I designed the prompt or post-processed the answers wrong.
# >   c. Does the model perform better under one of the evaluating approaches? Is it similar across true and false beliefs?
# Yes. The first approach produced better results than the multiple-choice generation format.

# %%
# note: only load the model again if you are in a different runtime than when you solved exercise 1
#!pip install -U datasets huggingface_hub fsspec
#
#lm_scorer = scorer.IncrementalLMScorer(
#  "allenai/OLMo-2-0425-1B-Instruct",
#   device
#)

# %%
# read the data (Note: you have to upload the file to your session in colab)
tom_back = pd.read_csv("/content/bigtom.csv")

# inspect the data and construct the evaluation prompts for standard scoring of sentence completions
tom_back["prompt_tb"] = tom_back["story"] + tom_back["tb_trigger"] + tom_back["final_sentence_prefix"]
tom_back["prompt_fb"] = tom_back["story"] + tom_back["fb_trigger"] + tom_back["final_sentence_prefix"]

# calculate the scores of the true belief condition with the true continuations
tb_scores_true = lm_scorer.conditional_score(
    # format the prompt into a list of same length as the number of answer options
    tom_back["prompt_tb"].tolist(),
    tom_back["tb_correct_continuation"]
)
# calculate the scores of the true belief condition with the false continuations
tb_scores_false = lm_scorer.conditional_score(
    tom_back["prompt_tb"].tolist(),
    tom_back["fb_correct_continuation"]
)

# calculate the accuracy of the true belief condition
tb_accuracy = np.array(tb_scores_true) > np.array(tb_scores_false)
print("True belief accuracy main ", tb_accuracy.mean())

# calculate the scores of the false belief condition with the true continuations
fb_scores_true = lm_scorer.conditional_score(
    tom_back["prompt_fb"].tolist(),
    tom_back["fb_correct_continuation"]

)
# calculate the scores of the false belief condition with the false continuations
fb_scores_false = lm_scorer.conditional_score(
    tom_back["prompt_fb"].tolist(),
    tom_back["tb_correct_continuation"]
)
# calculate the accuracy of the false belief condition
fb_accuracy = np.array(fb_scores_true) > np.array(fb_scores_false)
print("False belief accuracy main ", fb_accuracy.mean())
# Out:
# True belief accuracy main  0.54
# False belief accuracy main  0.74

# %%
# create the prompt for the multiple choice condition
def create_forced_choice_prompt(row):
    """
    Construct a prompt with the story, the trigger sentence,
    the task to choose the correct continuation for the the final sentence prefix,
    and the two continuations appended to the labels A, B.
    The order of the continuations is shuffled.

    Input:
    ------
    row: pandas Series
        Contains the story, trigger sentences, final sentence prefix, and continuations

    Returns:
    ------
    prompt_forced_choice_tb: str
        Forced choice prompt for true belief condition
    prompt_forced_choice_fb: str
        Forced choice prompt for false belief condition
    correct_label_tb: str
        Correct label for the correct true belief continuation (either "A" or "B", depending on the shuffling of the order of continuations)
    correct_label_fb: str
        Correct label for the correct false belief continuation (either "A" or "B", depending on the shuffling of the order of continuations)
    """
    # shuffle the order of the true and false continuations for both conditions

    tb_order = np.random.choice(["tb_correct_continuation", "fb_correct_continuation"], replace=False, size=2).tolist()
    fb_order = np.random.choice(["tb_correct_continuation", "fb_correct_continuation"], replace=False, size=2).tolist()
    task = " Choose the correct continuation for the following sentence: "
    # create the prompt for the forced choice task
    prompt_forced_choice_tb = row["story"] + row["tb_trigger"] + task  + row["final_sentence_prefix"] + " A. " + row[tb_order[0]] + " B." + row[tb_order[1]]
    prompt_forced_choice_fb = row["story"] +  row["fb_trigger"]+ task  + row["final_sentence_prefix"] + " A. " + row[fb_order[1]] + " B." + row[fb_order[0]]

    # get the correct labels for the true and false belief conditions
    correct_label_tb = ["A", "B"][tb_order.index("tb_correct_continuation")]
    correct_label_fb = ["A", "B"][fb_order.index("fb_correct_continuation")]
    return prompt_forced_choice_tb, prompt_forced_choice_fb, correct_label_tb, correct_label_fb


tom_fc_generation = tom_back.copy()

tom_fc_generation[[
    "prompt_forced_choice_tb",
    "prompt_forced_choice_fb",
    "correct_label_tb",
    "correct_label_fb"
]] = tom_back.apply(
    lambda row: create_forced_choice_prompt(row),
    axis=1,
    result_type="expand"
)

# %%
# Now evaluate the forced choice condition with generation
free_generation_accuracy_tb = []
free_generation_accuracy_fb = []

# set up the generation pipeline

from transformers import pipeline
generation_pipeline = pipeline(
    "text-generation",
    model = lm_scorer.model,
    device=device,
    tokenizer=lm_scorer.tokenizer,
)

for i, r in tom_fc_generation.iterrows():
    # generate the continuation for the true belief condition
    pred = generation_pipeline(
        r["prompt_forced_choice_tb"],
        max_new_tokens=5,
        temperature=0.7
    )
    # check if the prediction contains the correct label
    generated_text_tb = pred[0]['generated_text']
    print(generated_text_tb)
    answer_tb= generated_text_tb[len( r["prompt_forced_choice_tb"]):].strip()
    print(answer_tb)
    if answer_tb[0] == r["correct_label_tb"] :
        free_generation_accuracy_tb.append(1)
    else:
        free_generation_accuracy_tb.append(0)

    # generate the continuation for the false belief condition
    pred = generation_pipeline(
        r["prompt_forced_choice_fb"],
        max_new_tokens=5,
        temperature=0.7
    )
    # check if the prediction contains the correct label
    generated_text_fb = pred[0]['generated_text']
    answer_fb= generated_text_fb[len( r["prompt_forced_choice_fb"]):].strip()
    if answer_fb[0] == r["correct_label_fb"]:
        free_generation_accuracy_fb.append(1)
    else:
      free_generation_accuracy_fb.append(0)

# print the results
print("True belief accuracy (forced choice generation):", np.mean(free_generation_accuracy_tb))
print("False belief accuracy (forced choice generation):", np.mean(free_generation_accuracy_fb))
# Out:
# Naveen is a professional baker who runs a small bakery in a bustling city. Today, he plans to bake a large batch of chocolate chip cookies for an upcoming event. Naveen notices that the oven is preheated to the correct temperature. However, a sudden power outage causes the oven to turn off and cool down rapidly.Naveen waits for the power to return and the oven to reheat. Choose the correct continuation for the following sentence: Naveen believes the oven is A. affected by the power outage and has cooled down. B.preheated to the correct temperature. C.both affected and
# C.both affected and
# Eliza is a professional violinist preparing for a concert in a grand theater. She wants to play a beautiful piece on her violin to impress the audience. Eliza's violin is in perfect tune when she last checked it. Just before the concert, a sudden change in temperature causes the violin strings to become out of tune.Eliza notices the change in temperature. Choose the correct continuation for the following sentence: Eliza believes her violin is A. in perfect tune. B.out of tune. C. out of tune
# C. out of tune
# Hiroshi is a Japanese gardener tending to a zen garden in Kyoto. Hiroshi desires to create perfect harmony in the garden by carefully raking the sand into beautiful patterns. Hiroshi notices that the sand in the garden is smooth and untouched. A sudden gust of wind blows fallen leaves onto the sand, disrupting the smooth surface.Hiroshi sees the gust of wind and the leaves falling onto the sand. Choose the correct continuation for the following sentence: Hiroshi believes the sand is A. disrupted by fallen leaves. B.smooth and untouched. C. affected by the
# C. affected by the
# Amina is a baker in a bustling Moroccan market. She wants to bake a large batch of cookies for the market customers. Amina had just filled her oven with several trays of unbaked cookies. A sudden power outage occurs, shutting down Amina's electric oven and leaving the cookies half-baked.Amina decides to use her backup gas oven to finish baking the cookies. Choose the correct continuation for the following sentence: Amina believes the oven is full of A. unbaked cookies. B.half-baked cookies. C.undercooked cookies
# C.undercooked cookies
# Ravi is a fisherman in a coastal town in India, preparing his boat for a day of fishing. He plans to catch as many fish as possible to sell at the market. Ravi's boat has a small hole in its hull, which he secured the day before. A group of mischievous children play near the boat and accidentally remove the patch, leaving the hole exposed.Ravi decides to buy material to repair the hole. Choose the correct continuation for the following sentence: Ravi believes the hole in his boat is A. exposed. B.patched. C. repaired. D
# C. repaired. D
# Renata is a talented painter who lives in a small Italian village. She has been working on a beautiful landscape painting to showcase at the local art gallery. The painting is vibrant and full of life, just as Renata intended. Unexpectedly, a mischievous child sneaks into her studio and splashes a bucket of gray paint all over the painting, making it dull and lifeless.Renata decides to create a new painting from scratch. Choose the correct continuation for the following sentence: Renata believes her landscape painting is A. vibrant and full of life. B.now dull and lifeless. C. both A and
# C. both A and
# Tanya is a software engineer working on a new mobile application. She wants to ensure that the application runs smoothly and is free of bugs before launching it to the public. Tanya observes that the app's code appears to be well-structured and free of errors. However, a server malfunction corrupts some of the code, causing unexpected issues.Tanya notices the server malfunction. Choose the correct continuation for the following sentence: Tanya believes the app's code is A. corrupted due to a server malfunction. B.well-structured and free of errors. C. free of errors
# C. free of errors
# Heloise is a professional violinist performing at a prestigious concert hall. She wants to play a beautiful piece on her violin for the audience. She notices that the violin's strings are tuned perfectly before the performance. During intermission, a mischievous child sneaks backstage and detunes the violin's strings.Heloise discovers the detuned strings while checking her violin. Choose the correct continuation for the following sentence: Heloise believes the violin's strings are A. perfectly tuned. B.detuned. C.denoted by a
# C.denoted by a
# Amara is a botanist exploring a dense rainforest in search of a rare orchid species. Amara's goal is to find the rare orchid and study its unique characteristics. She spots an orchid with vibrant purple petals that she thinks might be the one she is searching for. As she continues to explore, a sudden downpour washes away the purple pigment from the orchid, revealing that it is actually a common white orchid.Amara continues her search for the rare orchid species. Choose the correct continuation for the following sentence: Amara believes the orchid A. with vibrant purple petals is the rare species. B.is a common white orchid. C. has another hidden
# C. has another hidden
# Gideon is a talented sculptor working in his studio in Italy. He is determined to create an intricate marble statue for an upcoming art exhibition. The block of marble he has chosen is solid and pristine. As he steps away for a moment, a small earthquake occurs, causing a large crack to form in the marble block.Gideon looks for a new block of marble to work with. Choose the correct continuation for the following sentence: Gideon believes the marble block is A. cracked and damaged. B.solid and pristine. C. both of these
# C. both of these
# Delia is a scientist working in a remote research station in Antarctica. She needs to collect important data from a weather monitoring device outside the station. Dalia sees that the device is displaying the correct data. Suddenly, a powerful solar flare disrupts the device's sensors, causing it to display incorrect data.Delia reads instructions to understand how to recalibrate the weather monitoring device to ensure accurate data collection. Choose the correct continuation for the following sentence: Delia believes the weather monitoring device is displaying A. incorrect data. B.correct data. C.none of these options
# C.none of these options
# Julius is at a community garden, tending to his vegetable plot. Julius wants to harvest some ripe tomatoes for dinner tonight. The tomatoes on the vine appear to be plump and ripe to Julius, with a vibrant red color. A sudden hailstorm strikes the garden, damaging the tomatoes and leaving them bruised and battered.Julius decides to salvage what he can from the damaged tomatoes. Choose the correct continuation for the following sentence: Julius believes the tomatoes are A. ripe and ready to be picked. B.bruised and battered. C. overripe and
# C. overripe and
# Yasmine is hiking through a dense forest on a warm summer day. Yasmine wants to find a freshwater source to refill her water bottle. She comes across a small stream that appears to be clean, clear and safe to drink. Suddenly, heavy rain begins to pour upstream, causing the stream to become murky and contaminated with dirt and debris.Yasmine notices the change in the water's appearance. Choose the correct continuation for the following sentence: Yasmine believes the stream water is A. murky and contaminated. B.clean and clear. C. safe and pure
# C. safe and pure
# Aria is a talented baker from Italy who has been asked to bake a cake for a friend's birthday party. She wants to create a delicious, multi-layered cake that will impress everyone. Aria has a fresh batch of ingredients ready to use for the cake. However, a mischievous cat sneaks into her kitchen and nibbles on some of the ingredients, making them no longer fresh.Aria goes to the store to buy new ingredients. Choose the correct continuation for the following sentence: Aria believes A. her ingredients are fresh and suitable for baking the cake. B.the ingredients are nibbled on and no longer fresh. C. she is allergic
# C. she is allergic
# Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task.Noor opens the fridge again and reaches for the oat milk. Choose the correct continuation for the following sentence: Noor believes the milk pitcher contains A. oat milk. B.almond milk. C.oat milk that
# C.oat milk that
# Isabella is a skilled baker in a small Italian town. She wants to bake a fresh batch of her famous ciabatta bread for the local market. Isabella has prepared the dough earlier and left it to rise in a warm spot in her kitchen. A curious cat enters the kitchen and jumps onto the counter, accidentally flattening the dough.Isabella sees the cat and the flattened dough. Choose the correct continuation for the following sentence: Isabella believes the dough has A. risen enough. B.been flattened. C. been kneaded
# C. been kneaded
# Aisha is a beekeeper in a small village near the Sahara Desert. Aisha wants to harvest honey from her beehives to sell at the local market. The beehives appear to be full of honey and ready for harvest. A sudden sandstorm blows through the area, filling the beehives with sand and making the honey difficult to extract.Aisha sees the sand-filled beehives after the sandstorm. Choose the correct continuation for the following sentence: Aisha believes the beehives are A. full of honey and ready for harvest. B.filled with sand. C. empty. D
# C. empty. D
# Ulysses is hiking in the mountains on a sunny day. Ulysses wants to take a photo of a rare bird perched on a tree nearby. He sees that the bird appears to be calm and still, sitting on a branch. Suddenly, a gust of wind blows through the area, startling the bird and causing it to fly away.Ulysses notices the bird flying away. Choose the correct continuation for the following sentence: Ulysses believes the bird is A. startled and flying away. B.calm and still. He then decides to chase
# He then decides to chase
# Ravi is a fisherman in a coastal town in India, preparing his boat for a day of fishing. He plans to catch as many fish as possible to sell at the market. Ravi's boat has a small hole in its hull, which he secured the day before. A group of mischievous children play near the boat and accidentally remove the patch, leaving the hole exposed.Ravi notices the children playing near his boat. Choose the correct continuation for the following sentence: Ravi believes the hole in his boat is A. exposed. B.patched. C. sealed. D
# C. sealed. D
# Mei is a talented cook who decides to participate in a local cooking competition. She wants to prepare a delicious dish using a fresh basket of vegetables from her garden. Mei sees that the vegetables are freshly picked and vibrant. Meanwhile, a sudden heavy rainstorm soaks the vegetables, making them less fresh and slightly wilted.Mei notices the rainstorm and the wet vegetables. Choose the correct continuation for the following sentence: Mei believes the vegetables are A. fresh and vibrant. B.wilted and less fresh. C. slightly wilted
# C. slightly wilted
# Carlos is a farmer in a small village in the Andes. Carlos wants to collect fresh eggs from his chickens to sell at the local market. The nest appears to be full of eggs when Carlos checks it in the morning. A crafty fox sneaks into the chicken coop and steals all the eggs from the nest.Carlos tries to chase the fox and recover the eggs. Choose the correct continuation for the following sentence: Carlos believes the A. fox has stolen the eggs. B.nest contains eggs. C. the eggs are
# C. the eggs are
# Priya is a professional baker in a small town in India. She wants to impress her customers with a delicious chocolate cake for a special event. Priya observes that the cake she has baked looks perfectly moist and fluffy. Suddenly, a power outage occurs, and the refrigerator storing the cake stops working, causing the cake to become dry and stale.Priya decides to bake a new chocolate cake. Choose the correct continuation for the following sentence: Priya believes the chocolate cake is A. dry and stale. B.moist and fluffy.  The correct answer is
# The correct answer is
# Kavya is a florist in a vibrant Indian market. Kavya wants to create a beautiful bouquet of fresh roses for a customer's anniversary celebration. Kavya sees a batch of roses in her shop that appear to be fresh and vibrant. Unbeknownst to her, a mischievous monkey sneaks into the shop and nibbles on the rose petals, leaving them damaged and unsuitable for the bouquet.Kavya notices the monkey's actions. Choose the correct continuation for the following sentence: Kavya believes the roses are A. damaged by the monkey. B.fresh and perfect for the bouquet. C. just slightly damaged
# C. just slightly damaged
# Uriel is a professional chef, preparing for a cooking competition. He wants to make sure his knife is sharp enough to cut through vegetables quickly and efficiently. Uriel tests the knife's sharpness by gently running his thumb along the edge. While Uriel is distracted, a fellow contestant accidentally knocks the knife onto the floor, causing the blade to become significantly duller.Uriel sees the knife falling onto the floor. Choose the correct continuation for the following sentence: Uriel believes the knife is A. sharp. B.significantly duller. C. sharp once more
# C. sharp once more
# Kwame is a skilled woodcarver in a small village in Ghana. Kwame wants to create a beautiful wooden sculpture of an elephant for his friend's birthday. He selects a block of wood from his workshop that appears to be solid and strong. However, as he begins to carve, he discovers a hidden pocket of termites inside the wood, rendering it unsuitable for his project.Kwame searches for a new block of wood to use for the sculpture. Choose the correct continuation for the following sentence: Kwame believes the block of wood A. contains termites. B.is sturdy and suitable for carving. C.is from a reputable
# C.is from a reputable
# Ravi is a farmer in a small Indian village, tending to his mango orchard. Ravi wants to harvest ripe mangoes to sell at the local market. He notices a mango tree with a heavy branch laden with ripe mangoes. A mischievous monkey comes along and eats all the ripe mangoes on the branch while Ravi is gathering his harvesting tools.Ravi sees the monkey eating the ripe mangoes. Choose the correct continuation for the following sentence: Ravi believes the branch has A. ripe mangoes. B.no ripe mangoes. C. many ripe mango
# C. many ripe mango
# Kofi is a chef at a popular Ghanaian restaurant. Kofi wants to prepare a traditional groundnut soup for the dinner menu. Kofi adds a small container of peanut butter to the soup pot on the stove. An apprentice chef, mistakenly thinking it was a seasoning paste, removes the peanut butter from the soup and replaces it with tomato paste.Kofi notices the apprentice chef swapping the ingredients. Choose the correct continuation for the following sentence: Kofi believes the soup contains A. peanut butter. B.tomato paste. C. a mix of
# C. a mix of
# Dalia is a professional photographer, setting up her equipment for a wedding photoshoot. She wants to capture stunning photos with her high-quality camera. Dalia sees that the camera lens appears clean and free of smudges. While Dalia is away, a mischievous child plays with the camera, leaving fingerprints all over the lens.Dalia reaches for her camera bag to fetch a cleaning cloth. Choose the correct continuation for the following sentence: Dalia believes the camera lens is A. clean and free of smudges. B.covered in fingerprints. B. covered in fingerprints
# B. covered in fingerprints
# Rohan is a potter in a small Indian village. Rohan wants to make a beautiful ceramic vase as a gift for his friend's housewarming party. Rohan selects a bag of high-quality clay in his workshop that appears to be soft and malleable. While Rohan is away for lunch, the hot sun dries the clay, making it hard and unworkable.Rohan discovers the dried, hard clay. Choose the correct continuation for the following sentence: Rohan believes the bag of clay is A. soft and malleable. B.hard and unworkable. C. perfect for making
# C. perfect for making
# Luka is a gardener working in a beautiful park in the middle of the city. Luka wants to water the plants in the park to ensure they stay healthy and vibrant. The sky is cloudy, and Luka assumes that it might rain soon. However, the wind picks up and blows the clouds away, revealing a bright and sunny sky.Luka notices the clouds clearing and the sun shining. Choose the correct continuation for the following sentence: Luka believes A. the weather has become sunny. B.that it will rain soon. C. that it might
# C. that it might
# Petra is a botanist researching the effects of different fertilizers on plant growth. She wants to find the best fertilizer for her experimental plants. Petra sees that the plants treated with Fertilizer A appear to be growing the fastest. However, a sudden infestation of insects damages the plants treated with Fertilizer A, stunting their growth.Petra decides to treat the plants with an insecticide before continuing her research. Choose the correct continuation for the following sentence: Petra believes the A. plants treated with Fertilizer A are growing the fastest. B.growth of the plants treated with Fertilizer A has been stunted. C.the insects prefer to
# C.the insects prefer to
# Farhan is a street food vendor in a bustling market in Istanbul. Farhan wants to prepare a delicious chicken shawarma wrap for a customer who asked for extra garlic sauce. Farhan takes a bottle of garlic sauce from the shelf and pours it onto the shawarma wrap. His assistant, who is busy preparing a different wrap, accidentally swaps the garlic sauce with a bottle of hot sauce, and Farhan unknowingly pours the hot sauce onto the shawarma wrap.Farhan considers swapping the hot sauce for the correct garlic sauce on the shawarma wrap. Choose the correct continuation for the following sentence: Farhan believes the sauce he poured is A. hot sauce. B.garlic sauce. C. Another brand of
# C. Another brand of
# Amina is an archaeologist working on an excavation site in Egypt. Amina wants to carefully remove a valuable artifact from the ground using her brush and trowel. The artifact appears to be intact and undamaged. Suddenly, the ground shifts slightly, causing a small crack to form on the artifact.Amina carefully removes the cracked artifact and documents the damage. Choose the correct continuation for the following sentence: Amina believes the artifact is A. cracked. B.in perfect condition. C. damaged by a
# C. damaged by a
# Hiroshi is a fisherman in a small coastal village in Japan. Hiroshi wishes to catch enough fish to feed his family and sell the surplus at the local market. The fishing nets are in excellent condition, ready to be cast into the sea. However, a curious pod of dolphins swims by and accidentally tears the nets with their sharp dorsal fins.Hiroshi sees the dolphins and the damage they caused to the nets. Choose the correct continuation for the following sentence: Hiroshi believes the fishing nets are A. torn by the dolphins. B.in excellent condition. C. beyond repair.
# C. beyond repair.
# Carlos is hiking in a dense forest on a sunny day. He wants to find a stream to refill his water bottle. He sees that the map he is carrying shows a stream nearby. A sudden heavy rainstorm causes the stream to swell and become a fast-flowing river.Carlos hears the heavy rain and the sound of rushing water. Choose the correct continuation for the following sentence: Carlos believes there is a A. stream nearby. B.fast-flowing river nearby. C. hidden cave nearby
# C. hidden cave nearby
# Amina is an archaeologist working on an excavation site in Egypt. Amina wants to carefully remove a valuable artifact from the ground using her brush and trowel. The artifact appears to be intact and undamaged. Suddenly, the ground shifts slightly, causing a small crack to form on the artifact.Amina notices the ground shift and the crack on the artifact. Choose the correct continuation for the following sentence: Amina believes the artifact is A. cracked. B.in perfect condition. C. undamaged.
# C. undamaged.
# Renata is a talented painter who lives in a small Italian village. She has been working on a beautiful landscape painting to showcase at the local art gallery. The painting is vibrant and full of life, just as Renata intended. Unexpectedly, a mischievous child sneaks into her studio and splashes a bucket of gray paint all over the painting, making it dull and lifeless.Renata catches the child in the act. Choose the correct continuation for the following sentence: Renata believes her landscape painting is A. now dull and lifeless. B.vibrant and full of life. C. neither dull nor
# C. neither dull nor
# Kofi is walking through a bustling marketplace in Accra, Ghana. He is searching for a rare, valuable coin to add to his collection. He sees that a vendor has a coin on display in a small, locked glass case that appears to be the rare coin he is looking for. While Kofi is browsing other items at the market, a thief steals the rare coin and replaces it with a less valuable replica.Kofi immediately alerts the vendor about the theft. Choose the correct continuation for the following sentence: Kofi believes the coin is a A. less valuable replica. B.rare, valuable one. C. neither a replica
# C. neither a replica
# Beatrice is a talented violinist, preparing for an important performance at a prestigious concert hall. She wants to ensure that her violin is perfectly tuned before she goes on stage. Beatrice checks the tuning of her violin and it sounds perfectly in tune. While Beatrice is in her dressing room, an assistant accidentally knocks the violin off the table, causing it to go out of tune.Beatrice sees that her violin has been knocked off the table. Choose the correct continuation for the following sentence: Beatrice believes her violin is A. perfectly tuned. B.out of tune. C. slightly out of
# C. slightly out of
# Alejandro is a professional baker in a small Mexican town. He plans to make a large batch of bread for the local market today. He observes that the yeast he has appears to be fresh and active. However, a sudden rise in temperature causes the yeast to become too active and over-ferment.Alejandro notices the change in the yeast's condition. Choose the correct continuation for the following sentence: Alejandro believes the yeast is A. in perfect condition for baking. B.over-fermented. C. just right for
# C. just right for
# Laila is an experienced hiker, exploring a dense forest on a solo expedition. She wants to find a nearby waterfall to enjoy a peaceful break. As she walks, Laila spots a clear trail leading deeper into the woods. Suddenly, a heavy downpour causes the trail to become muddy and difficult to navigate.Laila notices the trail becoming muddy due to the rain. Choose the correct continuation for the following sentence: Laila believes the trail is A. clear and easy to navigate. B.muddy and difficult to navigate. C. covered in fog
# C. covered in fog
# Haruki is exploring an ancient temple during his vacation in Cambodia. Haruki hopes to find a hidden chamber that contains a valuable artifact. He sees that the temple map he holds shows a secret passage leading to the chamber. A recent earthquake, unknown to Haruki, causes the secret passage to collapse, making it inaccessible.Haruki searches for an alternative route to the chamber. Choose the correct continuation for the following sentence: Haruki believes the secret passage A. has collapsed. B.exists. Haruki ponders if
# Haruki ponders if
# Nadia is a landscape architect working on a project to redesign a public park. She wants to create a beautiful and functional space that the community will enjoy. Nadia observes that the park's central fountain is in pristine condition. Overnight, vandals damage the fountain, leaving it in a state of disrepair.Nadia sees the damaged fountain the next day. Choose the correct continuation for the following sentence: Nadia believes the central fountain is in A. pristine condition. B.a state of disrepair. C. perfect condition.
# C. perfect condition.
# Emilia is a talented baker in a small Italian town. She plans to bake a large batch of biscotti to sell at the local market. Emilia inspects the oven's temperature, which appears to be set at the correct temperature for baking. A power surge causes the oven's temperature to spike, making it too hot for baking biscotti.Emilia notices the oven's temperature increase. Choose the correct continuation for the following sentence: Emilia believes the oven is A. too hot for baking biscotti. B.set at the correct temperature for baking biscotti. C. slightly hotter than
# C. slightly hotter than
# Luka is a skilled woodworker in a small Croatian village known for its traditional crafts. Luka intends to carve an intricate wooden sculpture as a gift for his friend's wedding. Luka spots a large piece of high-quality wood in his workshop. Just when Luka steps away for a moment, his dog chews on the wood, leaving teeth marks and damage to the surface.Luka looks for another piece of wood. Choose the correct continuation for the following sentence: Luka believes the wood is A. perfect for carving. B.damaged with teeth marks. C. not suitable for
# C. not suitable for
# Caden is a software engineer working on a groundbreaking app. Caden wants to test the app's performance on his smartphone. The app appears to be running smoothly and quickly on his phone. Suddenly, a system update on his phone causes the app to crash and become unresponsive.Caden sees the system update notification on his phone. Choose the correct continuation for the following sentence: Caden believes the app A. is functioning well. B.has crashed and become unresponsive. C. is slow and
# C. is slow and
# Ulysses is a zookeeper in a large city, responsible for taking care of a rare albino peacock. He wants to make sure the peacock is safely inside its enclosure before the zoo opens for the day. He sees that the peacock is perched on a branch inside the enclosure. A sudden gust of wind knocks the peacock off its perch, causing it to fly out of the enclosure and land in a nearby tree.Ulysses grabs a net to catch the peacock. Choose the correct continuation for the following sentence: Ulysses believes the albino peacock is A. inside the enclosure. B.outside in a nearby tree. C. somewhere else in
# C. somewhere else in
# Miguel is a chef at a popular restaurant in Mexico City. Miguel wants to prepare a delicious and authentic mole sauce for the evening's special dish. Miguel notices that the chocolate he has in the pantry is of high quality and perfect for the sauce. A sudden power outage causes the temperature in the pantry to rise, melting the chocolate.Miguel discovers the melted chocolate in the pantry. Choose the correct continuation for the following sentence: Miguel believes the chocolate A. is perfect for making the mole sauce. B.has melted. C. is good for
# C. is good for
# Isabela is a baker in a small Argentinian town known for its delicious pastries. Isabela wants to make a batch of alfajores, a traditional Argentinian dessert, for her bakery's customers. Isabela gets a bag of powdered sugar from her pantry to dust the alfajores. Her assistant, who was organizing the pantry earlier, accidentally placed a bag of flour in the powdered sugar's spot, and Isabela unknowingly grabs the bag of flour instead.Isabela finds the actual bag of powdered sugar and uses it to dust the alfajores. Choose the correct continuation for the following sentence: Isabela believes the bag she took from the pantry contains A. flour. B.powdered sugar. C. another unknown item
# C. another unknown item
# Mei, a talented pastry chef from a small town in China, is preparing to bake a large cake for a local celebration. Mei wants to use a specific cake mold to create a unique and intricate design. Mei sees the cake mold hanging on the wall, clean and ready for use. However, during a brief power outage, a gust of wind blows through the kitchen, knocking the cake mold off the wall and denting it severely.Mei notices the severely dented cake mold on the floor. Choose the correct continuation for the following sentence: Mei believes the cake mold is A. severely dented and unsuitable for use. B.clean and ready for use. C. still in one
# C. still in one
# True belief accuracy (forced choice generation): 0.02
# False belief accuracy (forced choice generation): 0.0

# %% [markdown]
# ## Exercise 4: How human-like are Llama's surprisals? (22 points)

# %% [markdown]
# More recently, work more informed by human language use and processing has compared LLMs’ performance to aspects of human behavior. Here, the assessment of LLMs is guided more by the question of how human-like certain aspects of its performance are. For instance, we might whether LLMs' 'knowledge' of language is comparable to human knowledge, and, in particular, whether the processing of language, given the knowledge , can be compared via system-appropriate linking measurements.
#
# Your task in this exercise is to assess whether the *surprisal* of different language models is comparable to human *reading times*, when it comes to processing subject-verb agreement. The linking hypothesis is that these can be considered the respective predictability, and therefore, processing load indicators.
# The conceptual ideas and the data are taken from [Wilcox et al. (2021)](https://arxiv.org/pdf/2106.03232) which was discussed in the lecture. Please read the sections 1-2.2 for the background (optionally, the rest, if you want).
# The data can be downloaded [here](https://github.com/CogSciPrag/Understanding-LLMs-course/tree/main/understanding-llms/homework/data/SVA_data.csv).
#
# The data provides human RTs and LM surprisals in different conditions for sentences where the subject and the verb either match (i.e., agree) or mismatch in terms of number. This is the main condition. Furthermore, the agreement manipulation occurs in different syntactic conditions, and for plural and singular nouns. Here are examples from the different syntactic conditions:
# * SRC (subject relative clause modifier):
#   * mismatch plural: The pilots that injured the teacher brings love to people.
#   * match plural: The pilots that injured the teacher bring love to people.
# * ORC (object relative clause modifier):
#   * mismatch plural: The ministers that the manager injured knows tennis.
#   * match plural: The ministers that the manager injured know tennis.
# * PP (prepositional phrase modifier):
#   * mismatch plural: The executives next to the teacher is good.
#   * match plural: The executives next to the teacher are good.
#
# The prediction is that humans and models should have difficulty processing the mismatched noun, both in the singular and the plural condition.
#
# > Your task is to complete / provide the following code and answer the following questions:
# > 1. Formulate a quantitatively testable hypothesis operationalizing the prediction above. I.e., formulate something like: if the prediction is true, X should be larger than Y.
# >*
# > If the prediction that human and models have difficulty processing the mismatched noun in both conditions is true, surprisal for both plural and singular cases should be higher for mismatch situtation than the match situation.
# > 2. Provide respective examples for the singular condition.
# >
# > - **SRC Mismatch/Match:** "The man who brings cake to work make everyone happy." /"The coworker who brings cake to work makes everyone happy."
# > - **ORC Mismatch/Match:** "The coworker that my friend punched decide to press charges." /"The coworker that my friend punched decides to press any charges."
# > - **PP Mismatch/Match:** "The family next to you are so cute." /"The family next to you is so cute."
# > 3. Inspect the data. What are the units of the provided results?
# > Directly quoted from the paper:
# > * "Surprisal is the inverse log probability of a word given its context: S(xi) =− log2 p(xi,x1,...,xi−1), measured in **bits** . So the columns ```match_plural, match_sing, mismatch_plural, mismatch_sing``` . Human reading times are in **miliseconds** , so when comparing them they used ms/bit(milliseconds of reaction time per bit of surprisal) conversion.
#
# > 4. Based on your hypothesis above, for each trial, calculate whether it holds or not. Plot the proportion of trials where your hypothesis is borne out (i.e, the accuracy), for humans and each model, in the singular and the plural condition. (Hint: use a barplot)
# > 5. Based on visual inspection, does any model match human performance?
# > For singular cases, most of the models match with human performance . However, in plural no model performs equivalent or better than humans.
# >
# > 6. Is either of the number conditions more difficult to process for humans or LMs?
# > It seems like singular mismatches are most common for humans when it is less common for models. Models perform worse when the sentence has plural mismatch.
# >
# > 7. Select the results for Llama and humans only. Is the processing 'difficulty' of Llama correlated with the processing slowdown of humans (across singular / plural conditions)? Interpret the correlation coefficient.

# %%
df = pd.read_csv("/content/SVA_data.csv")
df.head()
# Out:
#       suite  region_number group  model  match_plural  match_sing  \
# 0  SVNA-orc              7  1010   gpt2      7.740553    7.936675
# 1  SVNA-orc              7  1010   grnn      5.123765    4.921309
# 2  SVNA-orc              7  1010  human    633.333333  914.000000
# 3  SVNA-orc              7  1010   jrnn      4.376238    4.826594
# 4  SVNA-orc              7  1010  llama      5.940623    5.992930
#
#    mismatch_plural  mismatch_sing
# 0        11.336713       8.637131
# 1         5.999019       7.279292
# 2       733.000000    1012.125000
# 3         6.055298       6.815393
# 4        10.196010      10.679944

# %%
import pandas as pd

df['surprisal_sing'] = df['mismatch_sing'] > df['match_sing']
df['surprisal_plur'] = df['mismatch_plural'] > df['match_plural']

hypothesis_test = df.groupby('model').agg(
    surp_sing_mean=('surprisal_sing', 'mean'),
    surp_plur_mean=('surprisal_plur', 'mean')
).reset_index()

# %%
import matplotlib.pyplot as plt

# barplot of the results, by model and by condition (plural vs. singular)
bar_width = 0.3
index = range(len(hypothesis_test))

fig, ax = plt.subplots(figsize=(10,5))


bar1 = ax.bar([i - bar_width/2 for i in index], hypothesis_test['surp_sing_mean'], bar_width, label='Singular')
bar2 = ax.bar([i + bar_width/2 for i in index], hypothesis_test['surp_plur_mean'], bar_width, label='Plural')

ax.set_xticks(index)
ax.set_yticks(np.arange(0, 1.1, 0.05))
ax.set_xticklabels(hypothesis_test['model'], rotation=45)
ax.set_ylim(0,1)
ax.set_ylabel('Accuracy of Mismatch > Match in Trials')
ax.set_title('Hypothesis Test for Singular and Plural Conditions by Model')
ax.legend()
plt.tight_layout()
plt.show()
